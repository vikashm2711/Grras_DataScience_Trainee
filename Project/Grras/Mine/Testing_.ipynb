# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
bang=pd.read_csv("Dataset/internshala-jobs/BANGALORE.csv")
delhi=pd.read_csv("Dataset/internshala-jobs/DELHI.csv")
hyd=pd.read_csv("Dataset/internshala-jobs/HYDERABAD.csv")
inter=pd.read_csv("Dataset/internshala-jobs/INTERNATIONAL.csv")
kol=pd.read_csv("Dataset/internshala-jobs/KOLKATA.csv")
mum=pd.read_csv("Dataset/internshala-jobs/MUMBAI.csv")

# %%
df=pd.concat([bang, delhi, hyd, inter, kol, mum], ignore_index= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               3000 non-null   object
#  1   Date Time         3000 non-null   object
#  2   profile           3000 non-null   object
#  3   company           3000 non-null   object
#  4   Location          3000 non-null   object
#  5   Start Date        3000 non-null   object
#  6   Stipend           3000 non-null   object
#  7   Duration          3000 non-null   object
#  8   Apply by Date     3000 non-null   object
#  9   Offer             3000 non-null   object
#  10  Skills and Perks  3000 non-null   object
# dtypes: object(11)
# memory usage: 257.9+ KB

# %%
df.head()
# Out:
#                         _id            Date Time  \
# 0  5f9fc1e3fb43357b9094a297  2020-11-02 13:52:57
# 1  5f9fc1e4fb43357b9094a298  2020-11-02 13:52:59
# 2  5f9fc1e4fb43357b9094a299  2020-11-02 13:53:00
# 3  5f9fc1e5fb43357b9094a29a  2020-11-02 13:53:00
# 4  5f9fc1e6fb43357b9094a29b  2020-11-02 13:53:01
#
#                         profile                                company  \
# 0                Fashion Design                                 Enamor
# 1                    Operations             Lakshmi Tools & Components
# 2                   Photography                   Evineon Technologies
# 3        Social Media Marketing              VisualNet Private Limited
# 4  Business Development (Sales)  DM Consulting (India) Private Limited
#
#     Location   Start Date              Stipend  Duration Apply by Date  \
# 0  Bangalore  Immediately          5000 /month  2 Months    11 Nov' 20
# 1    Hoskote  Immediately         12000 /month   1 Month    16 Nov' 20
# ...

# %%
df.describe()
# Out:
#                              _id            Date Time  \
# count                       3000                 3000
# unique                      3000                 2443
# top     5f9fbec89ab4cb82f82fd8b1  2020-11-02 13:32:22
# freq                           1                    2
#
#                              profile  \
# count                           3000
# unique                           571
# top     Business Development (Sales)
# freq                             446
#
#                                                company Location   Start Date  \
# count                                             3000     3000         3000
# unique                                            1790       48            2
# top     Lloyd Harrington Australia Proprietary Limited    Delhi  Immediately
# freq                                                25      830         2979
#
#              Stipend  Duration Apply by Date       Offer Skills and Perks
# ...

# %%
df.Duration.value_counts()
# Out:
# 3 Months     1149
# 6 Months      993
# 2 Months      456
# 1 Month       184
# 4 Months      127
# 5 Months       32
# 2 Weeks        20
# 6 Weeks        19
# 1 Week          9
# 12 Months       4
# 4 Weeks         3
# 36 Months       3
# 24 Months       1
# Name: Duration, dtype: int64

# %%
df[['money','period']]=df['Stipend'].str.split('/', expand= True)

# %%
df[['m_min',"m_max"]]= df['money'].str.split('-', expand= True)

# %%
df
# Out:
#                            _id            Date Time  \
# 0     5f9fc1e3fb43357b9094a297  2020-11-02 13:52:57
# 1     5f9fc1e4fb43357b9094a298  2020-11-02 13:52:59
# 2     5f9fc1e4fb43357b9094a299  2020-11-02 13:53:00
# 3     5f9fc1e5fb43357b9094a29a  2020-11-02 13:53:00
# 4     5f9fc1e6fb43357b9094a29b  2020-11-02 13:53:01
# ...                        ...                  ...
# 2995  5f9fc6b25ae1fc3c5cd0d126  2020-11-02 14:13:29
# 2996  5f9fc6b35ae1fc3c5cd0d127  2020-11-02 14:13:30
# 2997  5f9fc6b55ae1fc3c5cd0d128  2020-11-02 14:13:31
# 2998  5f9fc6b75ae1fc3c5cd0d129  2020-11-02 14:13:33
# 2999  5f9fc7ce75696fcdf0e25d50  2020-11-02 14:18:13
#
#                            profile  \
# 0                   Fashion Design
# 1                       Operations
# 2                      Photography
# 3           Social Media Marketing
# 4     Business Development (Sales)
# ...                            ...
# 2995  Business Development (Sales)
# 2996        Mobile App Development
# ...

# %%
df['m_max'].value_counts(dropna=False)
# Out:
# NaN               1998
# 10000              197
# 12000              130
# 15000              116
# 8000                98
# 5000                85
# 7000                83
# 20000               60
# 6000                59
# 9000                24
# 4000                22
# 18000               18
# 3000                15
# 14000               15
# 25000               13
# 13000               10
# 11000                9
# 8500                 6
# 17000                5
# 2500                 5
# 16000                4
# 7500                 4
# 12500                3
# 1100                 3
# 30000                3
# 22000                2
# 3500                 2
# 24000                2
# 15000 lump sum       1
# 9500                 1
# 28000                1
# 40000                1
# 11500                1
# 14996                1
# 2002                 1
# 35000                1
# 25000 lump sum       1
# Name: m_max, dtype: int64

# %%
st['Stipend'].str.split("/").apply(lambda x: [sub.split(",") for sub in ])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-d85f70d84092> in <module>
# ----> 1 st['Stipend'].str.split("/")([sub.split(",") for sub in l])
#
# NameError: name 'l' is not defined

# %%
l = [ '2000 /month +  Incentives','2000 lump sum',  '8000-12000 /month']

# %%
def clean(x):
    x=x.split('/')
   
    if len(x)>1:
        y =x[1].strip()
    else:
        y=None
    
    if "lump sum" in x[0]:
        print(x)
        x=x[0].split(" ")
        min=x[0]
        max=x[0]
        y="lump sum"
        return min,max,y
        
    x=x[0].split('-')
    
    if len(x)>1:
        min=x[0]
        max=x[1]
    else:
        min = x[0]
        max = x[0]
    return min,max,y

# %%
clean(l[0])
# Out:
# ('2000 ', '2000 ', 'month +  Incentives')

# %%
df['moneys']=df['Stipend'].apply(lambda x: clean(x))

# %%
df[['min','max','Month']]=pd.DataFrame([*df.moneys], df.index)

# %%
df
# Out:
#                            _id            Date Time  \
# 0     5f9fc1e3fb43357b9094a297  2020-11-02 13:52:57
# 1     5f9fc1e4fb43357b9094a298  2020-11-02 13:52:59
# 2     5f9fc1e4fb43357b9094a299  2020-11-02 13:53:00
# 3     5f9fc1e5fb43357b9094a29a  2020-11-02 13:53:00
# 4     5f9fc1e6fb43357b9094a29b  2020-11-02 13:53:01
# ...                        ...                  ...
# 2995  5f9fc6b25ae1fc3c5cd0d126  2020-11-02 14:13:29
# 2996  5f9fc6b35ae1fc3c5cd0d127  2020-11-02 14:13:30
# 2997  5f9fc6b55ae1fc3c5cd0d128  2020-11-02 14:13:31
# 2998  5f9fc6b75ae1fc3c5cd0d129  2020-11-02 14:13:33
# 2999  5f9fc7ce75696fcdf0e25d50  2020-11-02 14:18:13
#
#                            profile  \
# 0                   Fashion Design
# 1                       Operations
# 2                      Photography
# 3           Social Media Marketing
# 4     Business Development (Sales)
# ...                            ...
# 2995  Business Development (Sales)
# 2996        Mobile App Development
# ...

# %%
df.drop(['m_min', 'm_max','moneys','Stipend'],axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               3000 non-null   object
#  1   Date Time         3000 non-null   object
#  2   profile           3000 non-null   object
#  3   company           3000 non-null   object
#  4   Location          3000 non-null   object
#  5   Start Date        3000 non-null   object
#  6   Duration          3000 non-null   object
#  7   Apply by Date     3000 non-null   object
#  8   Offer             3000 non-null   object
#  9   Skills and Perks  3000 non-null   object
#  10  money             3000 non-null   object
#  11  period            2899 non-null   object
#  12  min               3000 non-null   object
#  13  max               3000 non-null   object
#  14  Month             2899 non-null   object
# dtypes: object(15)
# memory usage: 351.7+ KB

# %%
df["Date Time"]=pd.to_datetime(df[["Date Time", "Apply by Date"]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-219-3f6540c8bb8d> in <module>
# ----> 1 df["Date Time"]=pd.to_datetime(df[["Date Time", "Apply by Date"]])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     806             result = arg._constructor(values, index=arg.index, name=arg.name)
#     807     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# --> 808         result = _assemble_from_unit_mappings(arg, errors, tz)
#     809     elif isinstance(arg, Index):
#     810         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _assemble_from_unit_mappings(arg, errors, tz)
#     905     if len(req):
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               3000 non-null   object
#  1   Date Time         3000 non-null   datetime64[ns]
#  2   profile           3000 non-null   object
#  3   company           3000 non-null   object
#  4   Location          3000 non-null   object
#  5   Start Date        3000 non-null   object
#  6   Duration          3000 non-null   object
#  7   Apply by Date     3000 non-null   object
#  8   Offer             3000 non-null   object
#  9   Skills and Perks  3000 non-null   object
#  10  money             3000 non-null   object
#  11  period            2899 non-null   object
#  12  min               3000 non-null   object
#  13  max               3000 non-null   object
#  14  Month             2899 non-null   object
# dtypes: datetime64[ns](1), object(14)
# ...

# %%
df["Apply by Date"].
# Out:
# 0       11 Nov' 20
# 1       16 Nov' 20
# 2       16 Nov' 20
# 3       16 Nov' 20
# 4       16 Nov' 20
#            ...
# 2995     9 Nov' 20
# 2996     6 Nov' 20
# 2997     5 Nov' 20
# 2998     2 Nov' 20
# 2999    16 Nov' 20
# Name: Apply by Date, Length: 3000, dtype: object

# %%
import datetime as datetime
df["Apply_by_Date"]=df["Apply by Date"].apply(lambda x: datetime.datetime.strptime(x,'%d %m %Y').strftime('%d-%m-%Y'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-226-2fa0ea961d1e> in <module>
#       1 import datetime as datetime
# ----> 2 df["Apply_by_Date"]=df["Apply by Date"].apply(lambda x: datetime.datetime.strptime(x,'%d %m %Y').strftime('%d-%m-%Y'))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-226-2fa0ea961d1e> in <lambda>(x)
#       1 import datetime as datetime
# ...

# %%
df['Apply_date']=df["Apply by Date"].str.replace("'","")

# %%
df
# Out:
#                            _id           Date Time  \
# 0     5f9fc1e3fb43357b9094a297 2020-11-02 13:52:57
# 1     5f9fc1e4fb43357b9094a298 2020-11-02 13:52:59
# 2     5f9fc1e4fb43357b9094a299 2020-11-02 13:53:00
# 3     5f9fc1e5fb43357b9094a29a 2020-11-02 13:53:00
# 4     5f9fc1e6fb43357b9094a29b 2020-11-02 13:53:01
# ...                        ...                 ...
# 2995  5f9fc6b25ae1fc3c5cd0d126 2020-11-02 14:13:29
# 2996  5f9fc6b35ae1fc3c5cd0d127 2020-11-02 14:13:30
# 2997  5f9fc6b55ae1fc3c5cd0d128 2020-11-02 14:13:31
# 2998  5f9fc6b75ae1fc3c5cd0d129 2020-11-02 14:13:33
# 2999  5f9fc7ce75696fcdf0e25d50 2020-11-02 14:18:13
#
#                            profile  \
# 0                   Fashion Design
# 1                       Operations
# 2                      Photography
# 3           Social Media Marketing
# 4     Business Development (Sales)
# ...                            ...
# 2995  Business Development (Sales)
# 2996        Mobile App Development
# ...
