# %%
import sqlalchemy as sal
import pandas as pd
from itertools import count

# %%
engine=sal.create_engine("mysql+pymysql://u681323537_grras_SQL:5;YbQ1!JtPpY@sql545.main-hosting.eu:3306/u681323537_learnsql")
conn =engine.connect()

# %%
guj= pd.read_sql_query("select * from covid where State ='Gujarat'", conn)
raj= pd.read_sql_query("select * from covid where State ='Rajasthan'", conn)

# %%
guj.reset_index(inplace=True)
raj.reset_index(inplace=True)

# %%
raj
# Out:
#      index  Vaccinated      State    F_dose    S_dose     total
# 0        0  16/01/2021  Rajasthan      9279         0      9279
# 1        1  18/01/2021  Rajasthan     23546         0     23546
# 2        2  19/01/2021  Rajasthan     30761         0     30761
# 3        3  20/01/2021  Rajasthan     32379         0     32379
# 4        4  21/01/2021  Rajasthan     32379         0     32379
# ..     ...         ...        ...       ...       ...       ...
# 232    232  07/09/2021  Rajasthan  35610155  11746858  47357013
# 233    233  08/09/2021  Rajasthan  36186863  12016323  48203186
# 234    234  09/09/2021  Rajasthan  36480293  12184364  48664657
# 235    235  10/09/2021  Rajasthan  36990638  12446279  49436917
# 236    236  11/09/2021  Rajasthan  37148474  12557462  49705936
#
# [237 rows x 6 columns]

# %%
raj['Vaccinated']=pd.to_datetime(raj['Vaccinated'])

# %%
raj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       237 non-null    int64
#  1   Vaccinated  237 non-null    datetime64[ns]
#  2   State       237 non-null    object
#  3   F_dose      237 non-null    int64
#  4   S_dose      237 non-null    int64
#  5   total       237 non-null    int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 11.2+ KB

# %%
import matplotlib.pyplot as plt


plt.rcParams['figure.figsize'] =10,5
plt.rcParams['figure.dpi'] =100

# %%
lines=plt.plot(guj['F_dose'], 'r--', raj['F_dose'], 'b--',guj['S_dose'], 'r-.', raj['S_dose'], 'b-.')
plt.legend(lines, ['Gujarat', 'Rajsthan'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] =10,5
plt.rcParams['figure.dpi'] =100

from matplotlib.animation import FuncAnimation
# %matplotlib notebook

# %%
for i in range(len(guj['F_dose'])):
    print(guj['F_dose'][i])
# Out:
# 10787
# 10787
# 17581
# 21832
# 34865
# 46150
# 78466
# 78466
# 91927
# 91927
# 94524
# 162616
# 221675
# 246054
# 247891
# 256097
# 287852
# 311251
# 348183
# 394416
# 438573
# 451002
# 505960
# 572412
# 614530
# 645439
# 667073
# 680326
# 683903
# 690074
# 695628
# 699443
# 811152
# 819060
# 821940
# 822193
# 824119
# 826583
# 830565
# 832737
# 833722
# 833722
# 833722
# 889167
# 979651
# 1028606
# 1156897
# 1295464
# 1420465
# 1421113
# 1589197
# 1709970
# 1734671
# 1744972
# 1871835
# 1981447
# 1992286
# 2129019
# 2259206
# 2293447
# 2475269
# 2682122
# 2916065
# 3120338
# 3341744
# 3572189
# 3759854
# 4012278
# 4277895
# 4524687
# 4616750
# 4628511
# 4828685
# 5024412
# 5459159
# 5812421
# 6127830
# 6552816
# 6817703
# 7110160
# 7224754
# 7501404
# 7749340
# 7983507
# 8156563
# 8343790
# 8502799
# 8623246
# 8730225
# 8814503
# 8921816
# 8992115
# 9083441
# 9181707
# 9251289
# 9329491
# 9412482
# 9496008
# 9550111
# 9634479
# 9719163
# 9787790
# 9874554
# 9965898
# 10159249
# ...

# %%
fig, ax= plt.subplots()
per= guj['F_dose'][:5].copy()
ax.plot(per, 'ro--')
def animatefunc(default):
    global per
    ax.clear ()
    per=np.delet(per,0)
    per= np.append(per, guj['F_dose'])
    ax.plot(per, '--')
    

f = FuncAnimation(fig, animatefunc, interval=1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x

# %%
import psutil
from time import sleep

# %%
cpu=[]
for i in range(10):
    cpu.append(psutil.cpu_percent())
    sleep(1)

# %%
fig, ax = plt.subplots()
per = cpu.copy()
ax.plot(per, 'ro--')
def animatefunc(default):
    global per
    ax.clear ()
    #per = np.delet(per,0)
    per = np.append(per, psutil.cpu_percent())
    ax.plot(per, 'ro--')

f = FuncAnimation(fig, animatefunc)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()

x = np.random.randint(1,10,10)
ax.plot(x, 'ro--')

def animatefunc(default):
    global x
    ax.clear ()
    x = np.delet(x,0)
    x = np.append(x, np.random.randint(1,20))
    ax.plot(x, 'ro--')

f = FuncAnimation(fig, animatefunc)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6470c9e96d69> in <module>
#       1 fig, ax = plt.subplots()
#       2
# ----> 3 x = np.random.randint(1,10,10)
#       4 ax.plot(x, 'ro--')
#       5
#
# NameError: name 'np' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
data = np.random.randn(800).reshape(10, 10, 8)
fig, ax = plt.subplots()

def animate(i):
    ax.clear()
    ax.contourf(data[:, :, i])

ani = animation.FuncAnimation(fig, animate, 5, interval=50, blit=False)
plt.show()

# %%
x=[]

def animate(i):
    global x
    x=i
    a=guj["F_dose"]
    b=raj["F_dose"]
    
    plt.cla()
    plt.plot(x,a, label = "Gujarat")
    plt.plot(x,b, label = "Rajsthan")
        
    plt.legend(loc="upper left")
    plt.tight_layout()
    sleep(1)
    i+=1
    
ani = FuncAnimation(plt.gcf(), animate, interval=1000)

plt.tight_layout()
plt.show()

# %%
plt.rcParams['animation.html']='jshtml'
fig, ax = plt.subplots()
fig.show()

# %%
plt.close()

# %%
i=0
data=[]
x=[]
y=[]

def animate2(i):
    guj1=guj
    raj1=raj
    x1=guj1['index']
    y1=guj1['F_dose']
    
    x2=raj1['index']
    y2=raj1['F_dose']
    
    plt.cla()
    
    plt.plot(x1,y1)
    plt.plot(x2,y2)
    
    plt.ylabel("F_dose")
    plt.xlabel("Time")
    plt.tight_layout()

ani = FuncAnimation(plt.gcf(), animate2, interval=10000)
plt.tight_layout()
plt.show()

# %%
import random
plt.close()

# %%
i=0
data=[]
x=[]
y=[]
index=count()

def animate(i):
    
    x.append(next(index))
    y.append(random.randint(0,5))
    
    plt.cla()
    
    plt.plot(x,y)
    
    plt.ylabel("F_dose")
    plt.xlabel("Time")
    plt.tight_layout()

ani = FuncAnimation(plt.gcf(), animate, interval=1000)
plt.tight_layout()
plt.show()

# %%
plt.close()

# %%
type(gc)

# %%
gc[:5]

# %%
fig,ax=  plt.subplots()

count=0
x= gc
z=gc[:5]
ax.plot(z, 'ro--')
def animate(i):
    global x
    ax.clear()
    sleep(100)
    x=np.delete(x,0)
    x=np.append(x,gc[next(count)])
    ax.plot(x, 'ro--')

    

f = FuncAnimation(fig, animate, interval=1000)
plt.show()

# %%
plt.close()

# %%
import matplotlib.pyplot as plt
from matplotlib import animation
import pandas as pd
# %matplotlib notebook

count=0
x=[]
g_f=[]
g_s=[]
r_f=[]
r_s=[]

def graph_(i):
    global count
    count +=1
    x.append(count)
    g_f.append(guj['F_dose'][count])
    g_s.append(guj['S_dose'][count])
    r_f.append(raj['F_dose'][count])
    r_s.append(raj['S_dose'][count])
    
    plt.cla()
    plt.plot(x,g_f)
    plt.plot(x,g_s)
    plt.plot(x,r_f)
    plt.plot(x,r_s)
    
anime=animation.FuncAnimation(plt.gcf(), graph_, interval=200)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %%
plt.close()

# %%
import matplotlib.pyplot as plt
from matplotlib import animation
import pandas as pd
# %matplotlib notebook

count=0
x=[]
g_f=[]
g_s=[]
r_f=[]
r_s=[]

def graph_(i):
    global count
    count +=1
    x.append(count)
    g_f.append(guj['F_dose'][count])
    g_s.append(guj['S_dose'][count])
    r_f.append(raj['F_dose'][count])
    r_s.append(raj['S_dose'][count])
    
    plt.cla()
    plt.plot(x,g_f)
    plt.plot(x,g_s)
    plt.plot(x,r_f)
    plt.plot(x,r_s)
    
    plt.xlabel("Time")
    plt.ylabel("Total number of Dose")
    
anime=animation.FuncAnimation(plt.gcf(), graph_, interval=200)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">
