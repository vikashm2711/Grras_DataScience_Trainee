# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
tip = sns.load_dataset("tips")
tit = sns.load_dataset("titanic")

# %%
plt.rcParams['figure.figsize'] = 11, 5
plt.rcParams['figure.dpi'] = 100

# %%
tit.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
tit.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
tit.drop(['who', 'embarked'], axis=1, inplace=True)

# %%
tit.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare  class  adult_male  \
# 0         0       3    male  22.0      1      0   7.2500  Third        True
# 1         1       1  female  38.0      1      0  71.2833  First       False
# 2         1       3  female  26.0      0      0   7.9250  Third       False
# 3         1       1  female  35.0      1      0  53.1000  First       False
# 4         0       3    male  35.0      0      0   8.0500  Third        True
#
#   deck  embark_town alive  alone
# 0  NaN  Southampton    no  False
# 1    C    Cherbourg   yes  False
# 2  NaN  Southampton   yes   True
# 3    C  Southampton   yes  False
# 4  NaN  Southampton    no   True

# %%
plt.bar(tip['tip'], tip['total_bill'], ec='k')
plt.show()

# %%
tip['sex'].value_counts().index
# Out:
# CategoricalIndex(['Male', 'Female'], categories=['Male', 'Female'], ordered=False, dtype='category')

# %%
tip['sex'].value_counts().values
# Out:
# array([157,  87], dtype=int64)

# %%
plt.bar(tip['sex'].value_counts().index, tip['sex'].value_counts().values)
plt.show()

# %%
plt.bar(tip['sex'].value_counts().index, tip['sex'].value_counts().values, width=0.2)
plt.show()

# %%
plt.bar(tip['sex'].value_counts().index, tip['sex'].value_counts().values, width=0.2, 
       color='red')
plt.show()

# %%
plt.bar(tip['sex'].value_counts().index, tip['sex'].value_counts().values, width=0.2, 
       color=['red', 'blue'])
plt.show()

# %%
i1 = tip['day'].value_counts().index
v1 = tip['day'].value_counts().values
plt.bar(i1, v1, color=['#123456', '#abcdef', '#abc123', '#abcf12'])
plt.show()

# %%
i1 = tip['day'].value_counts().index
v1 = tip['day'].value_counts().values

i2 = tip['time'].value_counts().index
v2 = tip['time'].value_counts().values
plt.bar(i1, v1, color=['#123456', '#abcdef', '#abc123', '#abcf12'])
plt.bar(i2, v2, color=['coral', 'indianred'])
plt.show()

# %%
cities = ['jaipur', 'delhi', 'gwalior', 'noida', 'gurgaon', 'indore']
vac_1 = [10000, 12000, 700, 7000, 5000, 9000]
vac_2 = [12000, 100000, 1500, 9000, 12000, 15000]
plt.bar(cities, vac_1, color='blue', alpha=0.5)
plt.bar(cities, vac_2, color='red', alpha=0.5)
plt.show()

# %%
cities = ['jaipur', 'delhi', 'gwalior', 'noida', 'gurgaon', 'indore']
vac_1 = [10000, 12000, 700, 7000, 5000, 9000]
vac_2 = [12000, 100000, 1500, 9000, 12000, 15000]
plt.bar(cities, vac_1, color='blue', alpha=0.5, bottom=vac_2)
plt.bar(cities, vac_2, color='red', alpha=0.5)
plt.show()

# %%
cities = ['jaipur', 'delhi', 'gwalior', 'noida', 'gurgaon', 'indore']
vac_1 = [10000, 12000, 700, 7000, 5000, 9000]
vac_2 = [12000, 100000, 1500, 9000, 12000, 15000]
plt.bar(cities, vac_1, color='blue', alpha=0.5)
plt.bar(cities, vac_2, color='red', alpha=0.5, bottom=vac_1)
plt.show()

# %%
cities = ['jaipur', 'delhi', 'gwalior', 'noida', 'gurgaon', 'indore']
vac_1 = [10000, 12000, 700, 7000, 5000, 9000]
vac_2 = [12000, 100000, 1500, 9000, 12000, 15000]
plt.bar(cities, vac_1, color='blue', alpha=0.5, width=0.5)
plt.bar(cities, vac_2, color='red', alpha=0.5, bottom=vac_1, align='edge', width=0.5)
plt.show()

# %%
cities = ['jaipur', 'delhi', 'gwalior', 'noida', 'gurgaon', 'indore']
vac_1 = [10000, 12000, 700, 7000, 5000, 9000]
vac_2 = [12000, 100000, 1500, 9000, 12000, 15000]
plt.bar(cities, vac_1, color='blue', alpha=0.5, width=0.5, align='edge')
plt.bar(cities, vac_2, color='red', alpha=0.5, bottom=vac_1, align='edge', width=0.5)
plt.show()

# %%
cities = ['jaipur', 'delhi', 'gwalior', 'noida', 'gurgaon', 'indore']
vac_1 = [10000, 12000, 700, 7000, 5000, 9000]
vac_2 = [12000, 100000, 1500, 9000, 12000, 15000]
plt.bar(cities, vac_1, color='blue', alpha=0.5, width=0.5, align='edge')
plt.bar(cities, vac_2, color='red', alpha=0.5, bottom=vac_1, width=0.5)
plt.show()

# %% [markdown]
# ### Axes

# %%
fig = plt.figure()
#plt.plot()

# %%
fig

# %%
fig

# %%
fig = plt.figure()
plt.plot()
# Out:
# []

# %%
fig

# %%
fig = plt.figure()
ax = fig.gca()
plt.plot()
# Out:
# []

# %%
ax
# Out:
# <AxesSubplot:>

# %%
print(dir(ax))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_add_text', '_adjustable', '_agg_filter', '_alias_map', '_alpha', '_anchor', '_animated', '_aspect', '_autoscaleXon', '_autoscaleYon', '_autotitlepos', '_axes', '_axes_class', '_axes_locator', '_axisbelow', '_box_aspect', '_clipon', '_clippath', '_contains', '_convert_dx', '_current_image', '_default_contains', '_facecolor', '_fill_between_x_or_y', '_frameon', '_gci', '_gen_axes_patch', '_gen_axes_spines', '_get_axis_list', '_get_axis_map', '_get_clipping_extent_bbox', '_get_lines', '_get_patches_for_fill', '_get_view', '_gid', '_gridOn', '_in_layout', '_init_axis', '_label', '_layoutbox', '_left_title', '_make_t
# ...

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1]) # x_coor, y_coord, height, width

# %%
ax

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 0.5, 0.5]) # x_coor, y_coord, height, width

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 0.5, 0.5]) # x_coor, y_coord, height, width
ax2 = fig.add_axes([0.5, 0.5, 0.5, 0.5])
