# %%
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings(action ='ignore')

plt.rcParams['figure.figsize'] =11,5
plt.rcParams['figure.dpi'] =100

# %%
iris = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')
diamonds = sns.load_dataset('diamonds')
fmri= sns.load_dataset('fmri')

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# Ques 1: dataset-- titanic
#
# <span class="burk">Create the fare distribution through a histogram as shown below.</span>
#
#
# ![image.png](attachment:image.png)

# %%
plt.hist('fare', bins=6)
# Out:
# (array([0., 0., 0., 1., 0., 0.]),
#  array([-0.5       , -0.33333333, -0.16666667,  0.        ,  0.16666667,
#          0.33333333,  0.5       ]),
#  <BarContainer object of 6 artists>)

# %% [markdown]
# Ques 2: dataset-- titanic
#     <span class="girk">Write a python program to create a boxplot for age and class group of all passengers.</span>
# ![image.png](attachment:image.png)

# %%
sns.boxplot(y=titanic['age'],x=titanic['class'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %% [markdown]
# Ques 3: dataset-- titanic <span class="girk">Create a bar chart for the number of male and female passengers.</span>
# ![image.png](attachment:image.png)

# %%
sns.countplot(x='sex', data = titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# Ques 4: dataset-- titanic
#     <span class="burk">Set up a grid to plot survival probability against several variables like class, sex, who and alone.
# Then Draw a seaborn pointplot onto each Axes</span>

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
fig, ax = sns.subplots(1, 4)

ax[0]=ax1.pointplot(x="class", y="survived", data=titanic)
ax[1]=ax2.pointplot(x="sex", y="survived", data=titanic)
ax[2]=ax3.pointplot(x="who", y="survived", data=titanic)
ax[3]=ax4.pointplot(x="alone", y="survived", data=titanic)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-5519e72208c8> in <module>
# ----> 1 fig, ax = sns.subplots(1, 4)
#       2
#       3 ax[0]=ax1.pointplot(x="class", y="survived", data=titanic)
#       4 ax[1]=ax2.pointplot(x="sex", y="survived", data=titanic)
#       5 ax[2]=ax3.pointplot(x="who", y="survived", data=titanic)
#
# AttributeError: module 'seaborn' has no attribute 'subplots'

# %%
diamonds.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
sns.barplot(x='cut', y= 'price', data= diamonds, hue=diamonds['color'])
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
sns.countplot(x='cut', data=diamonds)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='count'>

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.barplot()

# %%
fmri.columns
# Out:
# Index(['subject', 'timepoint', 'event', 'region', 'signal'], dtype='object')

# %%
sns.lineplot(x='timepoint', y='signal', hue='region', data= fmri)
sns.lineplot(x='timepoint', y='signal', hue='event', data= fmri)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.scatterplot(x='sepal_length',y='sepal_width', data= iris, hue='species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.displot(x='petal_length',hue='species', data = iris, kde= True)

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.jointplot(x='sepal_length',y='sepal_width', data = iris)

# %%
sns.pairplot(data=iris, palette='rainbow')
