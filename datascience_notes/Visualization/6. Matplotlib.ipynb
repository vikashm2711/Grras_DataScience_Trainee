# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("../Analysis/Pandas/Datasets/marketing_campaign.csv", sep="\t")
tip = sns.load_dataset("tips")

# %%
plt.rcParams['figure.figsize'] = 11, 5
plt.rcParams['figure.dpi'] = 100

# %%
plt.pie(tip['day'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-cf70a0c525b6> in <module>
# ----> 1 plt.pie(tip['day'])
#
# C:\Anaconda\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2825         textprops=None, center=(0, 0), frame=False,
#    2826         rotatelabels=False, *, normalize=None, data=None):
# -> 2827     return gca().pie(
#    2828         x, explode=explode, labels=labels, colors=colors,
#    2829         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# C:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# ...

# %%
plt.pie([10, 20, 30])
# Out:
# ([<matplotlib.patches.Wedge at 0x1c01d2be3d0>,
# ...
#  [Text(0.9526279355804298, 0.5500000148652441, ''),
#   Text(-0.5500000594609755, 0.9526279098330699, ''),
#   Text(1.0298943251329445e-07, -1.0999999999999954, '')])

# %%
plt.pie([10, 20, 30], labels=['shivam', 'hitesh', 'hanzal'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1c01d1fbbe0>,
# ...
#  [Text(0.9526279355804298, 0.5500000148652441, 'shivam'),
#   Text(-0.5500000594609755, 0.9526279098330699, 'hitesh'),
#   Text(1.0298943251329445e-07, -1.0999999999999954, 'hanzal')])

# %%
label = data['Education'].value_counts().index
val = data['Education'].value_counts().values

# %%
plt.pie(val, labels=label)
plt.show()

# %%
plt.bar(label, val)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(val, label)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(label, val)
# Out:
# <BarContainer object of 5 artists>

# %%
from generate_color import color_generate

# %%
plt.pie(val, labels=label, colors=[color_generate() for i in range(len(val))],
       autopct='%.1f')
plt.show()

# %%
help(plt.pie)
# Out:
# Help on function pie in module matplotlib.pyplot:
#
# pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=0, radius=1, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, normalize=None, data=None)
#     Plot a pie chart.
#
#     Make a pie chart of array *x*.  The fractional area of each wedge is
#     given by ``x/sum(x)``.  If ``sum(x) < 1``, then the values of *x* give
#     the fractional area directly and the array will not be normalized. The
#     resulting pie will have an empty wedge of size ``1 - sum(x)``.
#
#     The wedges are plotted counterclockwise, by default starting from the
#     x-axis.
#
#     Parameters
#     ----------
#     x : 1D array-like
#         The wedge sizes.
#
#     explode : array-like, default: None
#         If not *None*, is a ``len(x)`` array which specifies the fraction
# ...

# %%
plt.pie(val, labels=label, colors=[color_generate() for i in range(len(val))],
       autopct='%.1f', frame=True)
plt.show()

# %%
plt.pie(val, labels=label, colors=[color_generate() for i in range(len(val))],
       autopct='%.1f', frame=False, shadow=True)
plt.show()

# %%
plt.pie(val, labels=label, colors=[color_generate() for i in range(len(val))],
       autopct='%.1f', frame=False, shadow=True, explode=[0, 0.1, 0, 0, 0])
plt.show()

# %%
plt.pie(val, labels=label, colors=[color_generate() for i in range(len(val))],
       autopct='%.1f', frame=False, shadow=True, explode=[0, 0.1, 0.5, 0, 0])
plt.show()

# %%
plt.pie(val, labels=label, colors=[color_generate() for i in range(len(val))],
       autopct='%.1f', frame=False, shadow=True, explode=[1, 0.1, 0.5, 0.2, 0.3])
plt.show()

# %%
plt.pie(val, labels=label, colors=[color_generate() for i in range(len(val))],
       autopct='%.1f', frame=False, shadow=True, explode=[0.1, 0, 0, 0, 0])
plt.show()

# %%
plt.pie(val, labels=label, colors=[color_generate() for i in range(len(val))],
       autopct='%.1f', frame=False, shadow=True, explode=[0.1, 0, 0, 0, 0],
       pctdistance=0.9, labeldistance=0.4)
plt.show()

# %%
plt.pie(val, labels=label, colors=[color_generate() for i in range(len(val))],
       autopct='%.1f', frame=False, shadow=True, explode=[0.1, 0, 0, 0, 0],
       pctdistance=0.9, labeldistance=0.5)
plt.show()

# %%
plt.pie(val, labels=label, colors=[color_generate() for i in range(len(val))],
       autopct='%.1f', frame=False, shadow=True, explode=[0.1, 0, 0, 0, 0],
       pctdistance=0.9, labeldistance=1.2)
plt.show()

# %%
plt.pie(val, labels=label, colors=[color_generate() for i in range(len(val))],
       autopct='%.1f', frame=False, shadow=True, explode=[0.1, 0, 0, 0, 0],
       pctdistance=0.9, labeldistance=1.2, textprops={'color': '#123456', 'fontstyle': 'italic'})
plt.show()

# %%
plt.pie(val, labels=label, colors=[color_generate() for i in range(len(val))],
       autopct='%.1f', frame=False, explode=[0.1, 0, 0, 0, 0],
       pctdistance=0.9, labeldistance=1.2, wedgeprops={'ls': '--', 'lw': 10})
plt.show()

# %%
plt.pie(val, labels=label, colors=[color_generate() for i in range(len(val))],
       autopct='%.1f', frame=False, explode=[0.1, 0, 0, 0, 0],
       pctdistance=0.9, labeldistance=1.2, wedgeprops={'ls': '--', 'lw': 10},
       startangle=60)
plt.show()

# %%
fig = plt.figure(facecolor="black")
ax = plt.gca()
ax.set_facecolor("black")
plt.pie(val, labels=label, colors=[color_generate() for i in range(len(val))],
       autopct='%.1f', frame=False, explode=[0.1, 0, 0, 0, 0],
       pctdistance=0.9, labeldistance=1.2, wedgeprops={'ls': '--', 'lw': 10},
       startangle=60, textprops={'color': 'white'})
plt.show()

# %%
fig, ax = plt.subplots()
x = np.random.randint(1, 10, 10)
def func():
    ax.plot(x, x, 'ro--')

func()

# %%
x
# Out:
# array([9, 5, 4, 1, 8, 7, 2, 7, 4, 4])

# %%
fig, ax = plt.subplots()
ax.plot(x, 'ro--')
def animatefunc():
    global x
    x = np.delete(x, 0)
    x = np.append(x, np.random.randint(1, 20))
    ax.plot(x, 'ro--')

animatefunc()
