# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
tip = sns.load_dataset("tips")
iris = sns.load_dataset("iris")
tit = sns.load_dataset("titanic")

# %%
plt.rcParams['figure.figsize'] = 11, 5
plt.rcParams['figure.dpi'] = 100

# %%
plt.plot(tip['tip'], 'ro--')
plt.plot(tip['total_bill'], 'go--')

# %%
plt.plot(tip['tip'], 'ro--', tip['total_bill'], 'go--')
plt.show()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].value_counts()
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %%
plt.plot(iris['sepal_length'], iris['petal_length'], 'o', iris['sepal_width'], 
        iris['petal_width'], 'r*')

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
x = [1, 2, 3, 4, 5]
y = [3, 4, 2, 6, 5]
plt.plot(x, y)

# %%
x = [1, 2, 3, 4, 5]
y = [3, 4, 2, 6, 5]
plt.fill_between(x, y, x, y)

# %%
label = {'fontsize': 15, 'color': '#abc123', 'fontfamily': 'monospace'}
title = {'fontsize': 20, 'color': 'IndianRed', 'fontfamily': 'sans-serif'}

# %%
lines = plt.plot(iris['sepal_length'], iris['petal_length'], 'o', iris['sepal_width'], 
        iris['petal_width'], 'r*')
plt.legend(lines, ['Length', 'Width'])
plt.xlabel("Sepal", fontdict=label)
plt.ylabel("Petal", fontdict=label)
plt.show()

# %%
help(plt.legend)
# Out:
# Help on function legend in module matplotlib.pyplot:
#
# legend(*args, **kwargs)
#     Place a legend on the axes.
#
#     Call signatures::
#
#         legend()
#         legend(labels)
#         legend(handles, labels)
#
#     The call signatures correspond to three different ways how to use
#     this method.
#
#     **1. Automatic detection of elements to be shown in the legend**
#
#     The elements to be added to the legend are automatically determined,
#     when you do not pass in any extra arguments.
#
#     In this case, the labels are taken from the artist. You can specify
#     them either at artist creation or by calling the
#     :meth:`~.Artist.set_label` method on the artist::
#
#         line, = ax.plot([1, 2, 3], label='Inline label')
#         ax.legend()
#
#     or::
#
#         line, = ax.plot([1, 2, 3])
#         line.set_label('Label via method')
#         ax.legend()
#
#     Specific lines can be excluded from the automatic legend element
# ...

# %%
lines = plt.plot(iris['sepal_length'], iris['petal_length'], 'o', iris['sepal_width'], 
        iris['petal_width'], 'r*')
plt.legend(lines, ['Length', 'Width'], loc='upper left')
plt.xlabel("Sepal", fontdict=label)
plt.ylabel("Petal", fontdict=label)
plt.show()

# %%
lines = plt.plot(iris['sepal_length'], iris['petal_length'], 'o', iris['sepal_width'], 
        iris['petal_width'], 'r*')
plt.legend(lines, ['Length', 'Width'], loc='upper right')
plt.xlabel("Sepal", fontdict=label)
plt.ylabel("Petal", fontdict=label)
plt.show()

# %%
lines = plt.plot(iris['sepal_length'], iris['petal_length'], 'o', iris['sepal_width'], 
        iris['petal_width'], 'r*')
plt.legend(lines, ['Length', 'Width'], loc='lower right')
plt.xlabel("Sepal", fontdict=label)
plt.ylabel("Petal", fontdict=label)
plt.show()

# %%
lines = plt.plot(iris['sepal_length'], iris['petal_length'], 'o', iris['sepal_width'], 
        iris['petal_width'], 'r*')
plt.legend(lines, ['Length', 'Width'], loc=3)
plt.xlabel("Sepal", fontdict=label)
plt.ylabel("Petal", fontdict=label)
plt.show()

# %%
lines = plt.plot(iris['sepal_length'], iris['petal_length'], 'o', iris['sepal_width'], 
        iris['petal_width'], 'r*')
plt.legend(lines, ['Length', 'Width'], loc=2)
plt.xlabel("Sepal", fontdict=label)
plt.ylabel("Petal", fontdict=label)
plt.show()

# %%
lines = plt.plot(iris['sepal_length'], iris['petal_length'], 'o', iris['sepal_width'], 
        iris['petal_width'], 'r*')
plt.legend(lines, ['Length', 'Width'], loc=8)
plt.xlabel("Sepal", fontdict=label)
plt.ylabel("Petal", fontdict=label)
plt.show()

# %%
lines = plt.plot(iris['sepal_length'], iris['petal_length'], 'o', iris['sepal_width'], 
        iris['petal_width'], 'r*')
plt.legend(lines, ['Length', 'Width'], loc=[0, 0])
plt.xlabel("Sepal", fontdict=label)
plt.ylabel("Petal", fontdict=label)
plt.show()

# %%
lines = plt.plot(iris['sepal_length'], iris['petal_length'], 'o', iris['sepal_width'], 
        iris['petal_width'], 'r*')
plt.legend(lines, ['Length', 'Width'], loc=[0, 1])
plt.xlabel("Sepal", fontdict=label)
plt.ylabel("Petal", fontdict=label)
plt.show()

# %%
lines = plt.plot(iris['sepal_length'], iris['petal_length'], 'o', iris['sepal_width'], 
        iris['petal_width'], 'r*')
plt.legend(lines, ['Length', 'Width'], loc=[1, 0])
plt.xlabel("Sepal", fontdict=label)
plt.ylabel("Petal", fontdict=label)
plt.show()

# %%
lines = plt.plot(iris['sepal_length'], iris['petal_length'], 'o', iris['sepal_width'], 
        iris['petal_width'], 'r*')
plt.legend(lines, ['Length', 'Width'], loc=[0.5, 0.5])
plt.xlabel("Sepal", fontdict=label)
plt.ylabel("Petal", fontdict=label)
plt.show()

# %%
lines = plt.plot(iris['sepal_length'], iris['petal_length'], 'o', iris['sepal_width'], 
        iris['petal_width'], 'r*')
plt.legend(lines, ['Length', 'Width'], facecolor="black")
plt.xlabel("Sepal", fontdict=label)
plt.ylabel("Petal", fontdict=label)
plt.show()

# %%
lines = plt.plot(iris['sepal_length'], iris['petal_length'], 'o', iris['sepal_width'], 
        iris['petal_width'], 'r*')
plt.legend(lines, ['Length', 'Width'], facecolor="black", labelcolor='white',
          shadow=True)
plt.xlabel("Sepal", fontdict=label)
plt.ylabel("Petal", fontdict=label)
plt.show()

# %% [markdown]
# ### Scatter

# %%
plt.scatter(iris['sepal_length'], iris['sepal_width'])

# %%
plt.scatter(iris['sepal_length'], iris['petal_length'], color='red', marker='*')

# %%
plt.scatter(iris['sepal_length'], iris['petal_length'], color='red', marker='*', s=5)

# %%
plt.scatter(iris['sepal_length'], iris['petal_length'], color='red', marker='*', s=25)

# %%
color = iris['species'].map({'setosa': 'red', 'virginica': 'blue', 'versicolor': 'green'})

# %%
plt.scatter(iris['sepal_length'], iris['petal_length'], marker='*', c=iris['species'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4290             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4291                 colors = mcolors.to_rgba_array(c)
#    4292             except (TypeError, ValueError) as err:
#
# C:\Anaconda\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     340     else:
# --> 341         return np.array([to_rgba(cc, alpha) for cc in c])
#     342
#
# C:\Anaconda\lib\site-packages\matplotlib\colors.py in <listcomp>(.0)
#     340     else:
# --> 341         return np.array([to_rgba(cc, alpha) for cc in c])
#     342
#
# C:\Anaconda\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
# ...

# %%
color = iris['species'].map({'setosa': 'red', 'virginica': 'blue', 'versicolor': 'green'})

# %%
plt.scatter(iris['sepal_length'], iris['petal_length'], marker='*', c=color)

# %%
color = tip['day'].map({'Thur': 'blue', 'Fri': 'red', 'Sat': 'grey', 'Sun': 'green'})

# %%
size = tip['sex'].map({"Male": 5, 'Female': 20})

# %%
color = tip['day'].map({'Thur': 'blue', 'Fri': 'red', 'Sat': 'grey', 'Sun': 'green'})
size = tip['sex'].map({"Male": 5, 'Female': 20})
plt.scatter(tip['tip'], tip['total_bill'], c=color, s=size)
plt.plot([], 'o', color="red", label="Fri")
plt.plot([], 'o', color="blue", label="Thur")
plt.plot([], 'o', color="grey", label="Sat")
plt.plot([], 'o', color="green", label="Sun")
plt.legend()

# %% [markdown]
# #### New Dataset --> Analysis with plotting
