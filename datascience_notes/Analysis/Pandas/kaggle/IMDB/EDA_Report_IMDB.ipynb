# %% [markdown]
# # EDA_IMDB Dataset
#
# ### Context:
#
# - IMDb is the most popular movie website and it combines movie plot description, Metastore ratings, critic and user ratings and reviews, release dates, and many more aspects.
#
# - The website is well known for storing almost every movie that has ever been released (the oldest is from 1874 - "Passage de Venus") or just planned to be released (newest movie is from 2027 - "Avatar 5").
#
# - IMDb stores information related to more than 6 million titles (of which almost 500,000 are featured films) and it is owned by Amazon since 1998.
#
# ### Content:
#
# - The movies dataset includes 85,855 movies with attributes such as movie description, average rating, number of votes, genre, etc.
#
# - The ratings dataset includes 85,855 rating details from demographic perspective.
#
# - The names dataset includes 297,705 cast members with personal attributes such as birth details, death details, height, spouses, children, etc.
#
# - The title principals dataset includes 835,513 cast members roles in movies with attributes such as IMDb title id, IMDb name id, order of importance in the movie, role, and characters played.
#
#
# ## Objective:
#  - Analyze the data available on the IMDb website for movies released in the cinema between 1894 and 2011.
#
#
# ![image.png](attachment:image.png)
# ## Exploratory Data Analysis ( EDA )
# 1. Best language movie (avg_vote).
# 2. Top country using budget, and in which genere
# 3. How many movie start with the?
# 4. duration more than 100 and less than 100 any relation in ratings.?
# 5. Does duration effect the vote count ?
# 6. Least budgetted movie but high ratings
# 7. Top Country and there top language movies
# 8. highly rated actor
# 9. list of movie > 8 and gener Thriller.
# 10. Top Rated Sci-Fi Movies by Decades

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Loading the data set

# %%
movie=pd.read_csv("IMDb movies.csv", low_memory=False)

# %% [markdown]
# # Checking Introductory Details About Data

# %% [markdown]
# ### Basic Data Exploration
#
# This step, we will perform the below operations to check what the data set comprises of. We will check the below things:
#
#
# - The shape of the dataset
# - Head of the dataset
# - Info of the dataset
# - Summary of the dataset

# %%
movie.shape
# Out:
# (85855, 23)

# %%
movie.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  object
#  4   date_published         85855 non-null  object
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               85022 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
# ...

# %%
movie.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %% [markdown]
# ## Statistical Insight

# %%
movie.describe(include='all')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5ad413e5f73d> in <module>
# ----> 1 movie.describe(include='all')
#
# NameError: name 'movie' is not defined

# %% [markdown]
# ### Handling missing value

# %%
movie.isnull().sum()
# Out:
# imdb_title_id                0
# title                        0
# original_title               0
# year                         0
# date_published               0
# genre                        0
# duration                     0
# country                     64
# language                   833
# director                    87
# writer                    1572
# production_company        4455
# actors                      69
# description               2115
# avg_vote                     0
# votes                        0
# budget                   62145
# usa_gross_income         70529
# worlwide_gross_income    54839
# metascore                72550
# reviews_from_users        7597
# reviews_from_critics     11797
# dtype: int64

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Handling Duplicate records

# %%
duplicate=movie.duplicated()
print(duplicate.sum())
movie[duplicate]
# Out:
# 0
# Empty DataFrame
# Columns: [imdb_title_id, title, original_title, year, date_published, genre, duration, country, language, director, writer, production_company, actors, description, avg_vote, votes, budget, usa_gross_income, worlwide_gross_income, metascore, reviews_from_users, reviews_from_critics]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# - There was no duplicate records found in imdb dataset.

# %% [markdown]
# ### Handling Outlier

# %%
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %% [markdown]
# ## Explore Questions

# %% [markdown]
# ### Q1. Best language movie (avg_vote).

# %%
movie.groupby('language')['avg_vote'].sum().nlargest(10)
# Out:
# language
# English             197306.0
# French               23916.4
# Japanese             18396.2
# Spanish              17036.2
# Italian              16124.9
# Hindi                12372.7
# German               10490.4
# Russian               8428.7
# Turkish               7881.3
# English, Spanish      6739.4
# Name: avg_vote, dtype: float64

# %% [markdown]
# ### Q2. Top country using budget, and in which genere.

# %%
movie.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %% [markdown]
# ### Q3. How many movie start with the?

# %% [markdown]
# ### Q4. duration more than 100 and less than 100 any relation in ratings.?

# %% [markdown]
# ### longest duration and shortest duration movie

# %%
movie[movie['duration']==movie['duration'].min()][['title','duration','year']]
# Out:
#                                    title  duration  year
# 32798  Dragon Ball Z: La vendetta divina        41  1989

# %%
movie[movie['duration']==movie['duration'].max()][['title','duration','year']]
# Out:
#          title  duration  year
# 85057  La flor       808  2016

# %% [markdown]
# ### longer than 30 minutes and shorter than 60 minutes (short movies)

# %%
movie[(movie['duration']>=30) & (movie['duration']<=60) ].sort_values('duration')
# Out:
#       imdb_title_id                                              title  \
# 32798     tt0142235                  Dragon Ball Z: La vendetta divina
# 57390     tt1365598                                             Enigma
# 3966      tt0033949                                      Niagara Falls
# 54562    tt11443714  My Little Pony: Equestria Girls - Holidays Unw...
# 0         tt0000009                                         Miss Jerry
# ...             ...                                                ...
# 54537    tt11416594                            Karakomik Filmler: Deli
# 54570     tt1144805                                         King Lines
# 3947      tt0033890                                Meet Boston Blackie
# 46501     tt0431170           Joseph Smith: Prophet of the Restoration
# 24378     tt0096735  100 Jahre Adolf Hitler - Die letzte Stunde im ...
#
#                                           original_title  year date_published  \
# ...

# %% [markdown]
# ### Q4. duration more than 100 and less than 100 any relation in ratings.?

# %%
print('More than 100 duration > avg vote:',movie[movie['duration'] >=100]['avg_vote'].sum().round(2))
print('Less than 100 duration > avg vote:',movie[movie['duration'] < 100]['avg_vote'].sum().round(2))
# Out:
# More than 100 duration > avg vote: 225243.5
# Less than 100 duration > avg vote: 281185.6

# %% [markdown]
# ### Q4. dataframe with all movies rated greater than 8 and having more than 100000 votes

# %%
movie_highest=movie[(movie['avg_vote']>8) & (movie['votes'] > 500)]

# %%
movie_highest.head()
# Out:
#     imdb_title_id                             title  \
# 165     tt0010323  Il gabinetto del dottor Caligari
# 251     tt0012349                        Il monello
# 252     tt0012364        Il carrettiere della morte
# 334     tt0014429            Preferisco l'ascensore
# 372     tt0015064                   L'ultima risata
#
#                    original_title  year date_published  \
# 165  Das Cabinet des Dr. Caligari  1920     1920-02-27
# 251                       The Kid  1921     1923-11-26
# 252                     Körkarlen  1921           1922
# 334                  Safety Last!  1923     1924-12-08
# 372               Der letzte Mann  1924           1926
#
#                         genre  duration  country       language  \
# 165  Fantasy, Horror, Mystery        76  Germany         German
# 251     Comedy, Drama, Family        68      USA  English, None
# 252    Drama, Fantasy, Horror       107   Sweden        Swedish
# ...

# %% [markdown]
# $!@$FSA

# %% [markdown]
# ### One word movies data

# %%
movie['num_words_title'] = movie.apply(lambda x : len(x['title'].split(" ")),axis=1)
new_df = movie[movie['num_words_title']==1]
new_df.head()
# Out:
#    imdb_title_id       title original_title  year date_published  \
# 3      tt0002101   Cleopatra      Cleopatra  1912     1912-11-13
# 4      tt0002130   L'Inferno      L'Inferno  1911     1911-03-06
# 10     tt0002646    Atlantis       Atlantis  1913     1913-12-26
# 24     tt0003740     Cabiria        Cabiria  1914     1914-04-18
# 25     tt0003772  Cinderella     Cinderella  1914     1914-12-28
#
#                         genre  duration  country language  \
# 3              Drama, History       100      USA  English
# 4   Adventure, Drama, Fantasy        68    Italy  Italian
# 10                      Drama       121  Denmark   Danish
# 24  Adventure, Drama, History       148    Italy  Italian
# 25             Fantasy, Drama        52      USA  English
#
#                                director  ...  \
# 3                    Charles L. Gaskill  ...
# 4   Francesco Bertolini, Adolfo Padovan  ...
# 10                          August Blom  ...
# ...

# %%
new_df
# Out:
#       imdb_title_id       title original_title  year date_published  \
# 3         tt0002101   Cleopatra      Cleopatra  1912     1912-11-13
# 4         tt0002130   L'Inferno      L'Inferno  1911     1911-03-06
# 10        tt0002646    Atlantis       Atlantis  1913     1913-12-26
# 24        tt0003740     Cabiria        Cabiria  1914     1914-04-18
# 25        tt0003772  Cinderella     Cinderella  1914     1914-12-28
# ...             ...         ...            ...   ...            ...
# 85843     tt9900782      Kaithi         Kaithi  2019     2019-10-25
# 85844     tt9903716      Jessie         Jessie  2019     2019-03-15
# 85847     tt9905412       Ottam          Ottam  2019     2019-03-08
# 85848     tt9905462   Pengalila      Pengalila  2019     2019-03-08
# 85849     tt9906644   Manoharam      Manoharam  2019     2019-09-27
#
#                            genre  duration  country   language  \
# 3                 Drama, History       100      USA    English
# ...

# %% [markdown]
# ### Top 3 country movie producing

# %%
movie['country'].value_counts()[:3]
# Out:
# USA      28511
# India     6065
# UK        4111
# Name: country, dtype: int64

# %% [markdown]
# ### My Ratings

# %%
def my_rating(rating):
    if rating >=7:
        return "Good"
    elif rating >= 5:
        return "Average"
    else:
        return "Worst"

# %%
movie['my_rating']=movie['avg_vote'].apply(my_rating)

# %%
movie
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %% [markdown]
# ### Q5. Does duration effect the vote count ?

# %%
movie[['duration','avg_vote']].corr()
# Out:
#           duration  avg_vote
# duration  1.000000  0.242432
# avg_vote  0.242432  1.000000

# %% [markdown]
# ### Q6. Least budgetted movie but high ratings

# %% [markdown]
# ### Q7. Top Country and there top language movies

# %%
movie.groupby('country')['language'].value_counts()
# Out:
# country                           language
# Afghanistan, France               Dari                                        1
#                                   Dari, Pushto                                1
# Afghanistan, France, Germany, UK  Persian                                     1
# Afghanistan, Iran                 Persian, Dari                               2
#                                   Persian                                     1
#                                                                              ..
# Yugoslavia, USA, Liechtenstein    Serbo-Croatian, English                     1
# Yugoslavia, West Germany          Serbo-Croatian                              2
#                                   Serbo-Croatian, English, Russian, German    1
# Zambia, Sweden                    English                                     1
# Zimbabwe                          English                                     1
# Name: language, Length: 11367, dtype: int64

# %% [markdown]
# ### Q8. highly rated actor

# %% [markdown]
# ### Q9. list of movie > 8 and gener Thriller.

# %%
def thriller(x,genre):
    if x in genre:
        return True
    else:
        return False

# %%
movx=movie[['title','genre']].apply(lambda x: thriller('Horror',movie['genre']))

# %%
movx
# Out:
# title    False
# genre    False
# dtype: bool

# %%
movie[movie['avg_vote'] > 8]
# Out:
#       imdb_title_id                             title  \
# 165       tt0010323  Il gabinetto del dottor Caligari
# 251       tt0012349                        Il monello
# 252       tt0012364        Il carrettiere della morte
# 334       tt0014429            Preferisco l'ascensore
# 372       tt0015064                   L'ultima risata
# ...             ...                               ...
# 85728     tt9766160                        Damayanthi
# 85769     tt9811598                             Chaos
# 85828     tt9886872                  Munthiri Monchan
# 85843     tt9900782                            Kaithi
# 85848     tt9905462                         Pengalila
#
#                      original_title  year date_published  \
# 165    Das Cabinet des Dr. Caligari  1920     1920-02-27
# 251                         The Kid  1921     1923-11-26
# 252                       Körkarlen  1921           1922
# 334                    Safety Last!  1923     1924-12-08
# ...

# %% [markdown]
# ### Q10. Top Rated Sci-Fi Movies by Decades

# %% [markdown]
# ## Research Questions

# %% [markdown]
# ## Correlations

# %%
movie.corr()
# Out:
#                       duration  avg_vote     votes  metascore  \
# duration              1.000000  0.242432  0.125618   0.210531
# avg_vote              0.242432  1.000000  0.166972   0.691338
# votes                 0.125618  0.166972  1.000000   0.194730
# metascore             0.210531  0.691338  0.194730   1.000000
# reviews_from_users    0.130836  0.138185  0.766237   0.126131
# reviews_from_critics  0.135465  0.200526  0.671635   0.236107
#
#                       reviews_from_users  reviews_from_critics
# duration                        0.130836              0.135465
# avg_vote                        0.138185              0.200526
# votes                           0.766237              0.671635
# metascore                       0.126131              0.236107
# reviews_from_users              1.000000              0.671634
# reviews_from_critics            0.671634              1.000000

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The apply and lambda functions allow you to handle a variety of difficult tasks while modifying data.
#
# I don’t think I need to be worried about anything when using Pandas because I can use them effectively.
#
# I tried to describe how it works in this post. There may be more ways of achieving what I’ve just described.
#
# However, I prefer to apply/lambda to map/apply map because it is more readable and more suited to my workflow.

# %% [markdown]
# ## EndNote
#
# Thank you for reading!
# I hope you enjoyed the article and increased your knowledge.
# Please feel free to contact me on Email
# Something not mentioned or want to share your thoughts? Feel free to comment below And I’ll get back to you.
#
# Connect with me on Linkedin <br>
# Connect with me on Github
