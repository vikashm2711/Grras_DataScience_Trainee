# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sal = pd.read_csv("Datasets/Salaries.csv")

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
x = sal['JobTitle'].apply(lambda x: len(x))
y = sal['TotalPayBenefits']

# %%
x = sal['JobTitle'].apply(lambda x: len(x))
y = sal['TotalPayBenefits']
 
co = (((x-x.mean())*(y-y.mean())).sum())/(np.sqrt((((x-x.mean())**2).sum())*(((y-y.mean())**2).sum())))
co
# Out:
# -0.03687844593260673

# %%
a = ((x - x.mean())*(y - y.mean())).sum()
b = np.sqrt((((x - x.mean())**2).sum()) * (((y - y.mean())**2).sum()))
a/b
# Out:
# -0.03687844593260673

# %%
np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.03687845],
#        [-0.03687845,  1.        ]])

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %% [markdown]
#     Top 5 job titles having highest salaries

# %%
sal['TotalPay'].sort_values()
# Out:
# 148653      -618.13
# 106745         0.00
# 106746         0.00
# 106747         0.00
# 106748         0.00
#             ...
# 36159     362844.66
# 110532    390111.98
# 110531    471952.64
# 1         538909.28
# 0         567595.43
# Name: TotalPay, Length: 148654, dtype: float64

# %%
sal.sort_values(by='TotalPayBenefits', ascending=False)['JobTitle'][:5]
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 110531                                    Deputy Chief 3
# 110532                                 Asst Med Examiner
# 110533                          Chief Investment Officer
# Name: JobTitle, dtype: object

# %%
sal[['JobTitle', 'TotalPayBenefits']].sort_values(by='TotalPayBenefits', ascending=False)['JobTitle'][:5]
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 110531                                    Deputy Chief 3
# 110532                                 Asst Med Examiner
# 110533                          Chief Investment Officer
# Name: JobTitle, dtype: object

# %%
sal.sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-72f5f44c1c83> in <module>
# ----> 1 sal.sort_values()
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
tip = sns.load_dataset("tip")
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# C:\Anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1353             try:
# -> 1354                 h.request(req.get_method(), req.selector, req.data, headers,
#    1355                           encode_chunked=req.has_header('Transfer-encoding'))
#
# C:\Anaconda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# C:\Anaconda\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...

# %%
help(sns.load_dataset)
# Out:
# Help on function load_dataset in module seaborn.utils:
#
# load_dataset(name, cache=True, data_home=None, **kws)
#     Load an example dataset from the online repository (requires internet).
#
#     This function provides quick access to a small number of example datasets
#     that are useful for documenting seaborn or generating reproducible examples
#     for bug reports. It is not necessary for normal usage.
#
#     Note that some of the datasets have a small amount of preprocessing applied
#     to define a proper ordering for categorical variables.
#
#     Use :func:`get_dataset_names` to see a list of available datasets.
#
#     Parameters
#     ----------
#     name : str
#         Name of the dataset (``{name}.csv`` on
#         https://github.com/mwaskom/seaborn-data).
#     cache : boolean, optional
#         If True, try to load from the local cache first, and save to the cache
#         if a download is required.
#     data_home : string, optional
# ...

# %%
sal.sort_values("TotalPay")[:5]
# Out:
#             Id           EmployeeName                    JobTitle  BasePay  \
# 148653  148654              Joe Lopez  Counselor, Log Cabin Ranch      0.0
# 106745  106746        Tiffany M Rasso         Recreation Director      NaN
# 106746  106747       Bertha  Robinson            Transit Operator      NaN
# 106747  106748       Kermith T Miller             Utility Plumber      NaN
# 106748  106749  Rita I Sinasohn-Pharr                Clerk Typist      NaN
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148653          0.0   -618.13      0.00   -618.13           -618.13  2014
# 106745          0.0      0.00   7959.18      0.00           7959.18  2013
# 106746          0.0      0.00   7959.18      0.00           7959.18  2013
# 106747          0.0      0.00   7959.18      0.00           7959.18  2013
# 106748          0.0      0.00   7959.18      0.00           7959.18  2013
#
#         Notes         Agency  Status
# ...

# %%
sal.sort_index()
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
sal.sort_values(['TotalPay'])[['TotalPay', 'TotalPayBenefits']][:5]
# Out:
#         TotalPay  TotalPayBenefits
# 148653   -618.13           -618.13
# 106745      0.00           7959.18
# 106746      0.00           7959.18
# 106747      0.00           7959.18
# 106748      0.00           7959.18

# %%
sal.sort_values(['TotalPay', 'TotalPayBenefits'])[['TotalPay', 'TotalPayBenefits']][:10]
# Out:
#         TotalPay  TotalPayBenefits
# 148653   -618.13           -618.13
# 110530      0.00            -33.89
# 110529      0.00             -8.20
# 110528      0.00             -2.73
# 36156       0.00              0.00
# 36157       0.00              0.00
# 36158       0.00              0.00
# 148626      0.00              0.00
# 148627      0.00              0.00
# 148628      0.00              0.00

# %%
sal.sort_values(['TotalPay', 'TotalPayBenefits', 'BasePay'])[:5]
# Out:
#             Id      EmployeeName                                    JobTitle  \
# 148653  148654         Joe Lopez                  Counselor, Log Cabin Ranch
# 110530  110531     David P Kucia                            Police Officer 3
# 110529  110530    Mark E Laherty                            Police Officer 3
# 110528  110529  Timothy E Gibson                            Police Officer 3
# 36156    36157    PAULETTE ADAMS  STATIONARY ENGINEER, WATER TREATMENT PLANT
#
#         BasePay  OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  \
# 148653      0.0          0.0   -618.13      0.00   -618.13           -618.13
# 110530      NaN          0.0      0.00    -33.89      0.00            -33.89
# 110529      NaN          0.0      0.00     -8.20      0.00             -8.20
# 110528      NaN          0.0      0.00     -2.73      0.00             -2.73
# 36156       0.0          0.0      0.00       NaN      0.00              0.00
#
# ...

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
sal['Year'].value_counts()
# Out:
# 2014    38123
# 2013    37606
# 2012    36766
# 2011    36159
# Name: Year, dtype: int64

# %% [markdown]
#     Top 5 paid job titles according to year
#             2011 --> 5
#             2012 --> 5
#             2013 --> 5
#             2014 --> 5

# %%
sal.groupby(["Year", "JobTitle"]).count().head()
# Out:
#                              Id  EmployeeName  BasePay  OvertimePay  OtherPay  \
# Year JobTitle
# 2011 ACCOUNT CLERK           83            83       83           83        83
#      ACCOUNTANT               5             5        5            5         5
#      ACCOUNTANT INTERN       48            48       48           48        48
#      ACUPUNCTURIST            1             1        1            1         1
#      ADMINISTRATIVE ANALYST  93            93       93           93        93
#
#                              Benefits  TotalPay  TotalPayBenefits  Notes  \
# Year JobTitle
# 2011 ACCOUNT CLERK                  0        83                83      0
#      ACCOUNTANT                     0         5                 5      0
#      ACCOUNTANT INTERN              0        48                48      0
#      ACUPUNCTURIST                  0         1                 1      0
#      ADMINISTRATIVE ANALYST         0        93                93      0
#
# ...

# %%
sal.groupby(["Year", "JobTitle"]).count().sort_values("Id")
# Out:
#                                        Id  EmployeeName  BasePay  OvertimePay  \
# Year JobTitle
# 2014 Youth Comm Advisor                 1             1        1            1
# 2012 Chief Fire Alarm Dispatcher        1             1        1            1
# 2014 Conservatorship/Case Mgt Sprv      1             1        1            1
# 2012 Chief Electrical Inspector         1             1        1            1
#      Chief Dep Adlt Prob Of (SFERS)     1             1        1            1
# ...                                   ...           ...      ...          ...
# 2014 Special Nurse                   1478          1478     1478         1478
# 2012 Transit Operator                2262          2262     2262         2262
# 2013 Transit Operator                2295          2295     2234         2295
# 2011 TRANSIT OPERATOR                2388          2388     2388         2388
# 2014 Transit Operator                2479          2479     2479         2479
#
# ...

# %%
sal[sal['TotalPayBenefits'].isin([0, 0, 1])]
# Out:
#             Id            EmployeeName  \
# 36156    36157          PAULETTE ADAMS
# 36157    36158           KAUKAB MOHSIN
# 36158    36159      JOSEPHINE MCCREARY
# 148626  148627           Paulet Gaines
# 148627  148628        Brett A Lundberg
# 148628  148629          Mark W Mcclure
# 148629  148630       Elizabeth Iniguez
# 148630  148631            Randy J Keys
# 148631  148632         Andre M Johnson
# 148632  148633  Sharon D Owens-Webster
# 148633  148634        Edward Ferdinand
# 148634  148635          David M Turner
# 148635  148636     James S Kibblewhite
# 148636  148637           Andrew J Enzi
# 148637  148638        Kadeshra D Green
# 148638  148639    Lennard B Hutchinson
# 148639  148640       Richard A Talbert
# 148640  148641      Charlene D Mccully
# 148641  148642   Raphael Marquis Goins
# 148642  148643       Dominic C Marquez
# 148643  148644              Kim Brewer
# 148644  148645            Randy D Winn
# 148645  148646        Carolyn A Wilson
# ...

# %%
temp = sal[sal['TotalPayBenefits'].isin(sal.groupby("Year")['TotalPayBenefits'].nlargest(5))]

# %%
temp[['JobTitle', 'Year']]
# Out:
#                                               JobTitle  Year
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  2011
# 1                      CAPTAIN III (POLICE DEPARTMENT)  2011
# 2                      CAPTAIN III (POLICE DEPARTMENT)  2011
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC  2011
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  2011
# 36159                     Lieutenant, Fire Suppression  2012
# 36160                                  Chief of Police  2012
# 36161                      Electronic Maintenance Tech  2012
# 36162                           Chief, Fire Department  2012
# 36163                        EMT/Paramedic/Firefighter  2012
# 72925                                  Chief of Police  2013
# 72926                           Chief, Fire Department  2013
# 72927                   Battalion Chief, Fire Suppress  2013
# 72928                                Asst Med Examiner  2013
# ...

# %% [markdown]
#     You have to get each element at index 1 of a tuple of multi index

# %%
index = []
for i in sal.groupby("Year")['TotalPayBenefits'].nlargest(5).index:
    index.append(i[1])

# %%
sal.groupby("Year")['TotalPayBenefits'].nlargest(5)
# Out:
# Year
# 2011  0         567595.43
#       1         538909.28
#       2         335279.91
#       3         332343.61
#       4         326373.19
# 2012  36159     407274.78
#       36160     391362.30
#       36161     389496.02
#       36162     386807.48
#       36163     381643.11
# 2013  72925     425815.28
#       72926     422353.40
#       72927     404167.27
#       72928     401736.88
#       72929     398421.67
# 2014  110531    510732.68
#       110532    479652.21
#       110533    436224.36
#       110534    418019.22
#       110535    417435.10
# Name: TotalPayBenefits, dtype: float64

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
index
# Out:
# [0,
#  1,
#  2,
#  3,
#  4,
#  36159,
#  36160,
#  36161,
#  36162,
#  36163,
#  72925,
#  72926,
#  72927,
#  72928,
#  72929,
#  110531,
#  110532,
#  110533,
#  110534,
#  110535]

# %%
sal.iloc[index][['Year', 'JobTitle']]
# Out:
#         Year                                        JobTitle
# 0       2011  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       2011                 CAPTAIN III (POLICE DEPARTMENT)
# 2       2011                 CAPTAIN III (POLICE DEPARTMENT)
# 3       2011            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4       2011    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 36159   2012                    Lieutenant, Fire Suppression
# 36160   2012                                 Chief of Police
# 36161   2012                     Electronic Maintenance Tech
# 36162   2012                          Chief, Fire Department
# 36163   2012                       EMT/Paramedic/Firefighter
# 72925   2013                                 Chief of Police
# 72926   2013                          Chief, Fire Department
# 72927   2013                  Battalion Chief, Fire Suppress
# 72928   2013                               Asst Med Examiner
# ...

# %%
sal.groupby(['JobTitle', 'Year']).count().index
# Out:
# MultiIndex([(                                 'ACCOUNT CLERK', 2011),
#             (                                    'ACCOUNTANT', 2011),
#             (                             'ACCOUNTANT INTERN', 2011),
#             (                   'ACPO,JuvP, Juv Prob (SFERS)', 2014),
#             (                                 'ACUPUNCTURIST', 2011),
#             (                        'ADMINISTRATIVE ANALYST', 2011),
#             (                     'ADMINISTRATIVE ANALYST II', 2011),
#             (                    'ADMINISTRATIVE ANALYST III', 2011),
#             (                       'ADMINISTRATIVE ENGINEER', 2011),
#             (               'ADMINISTRATIVE SERVICES MANAGER', 2011),
#             ...
#             (                'Worker's Compensation Adjuster', 2014),
#             (                         'X-RAY LABORATORY AIDE', 2011),
#             (                         'X-Ray Laboratory Aide', 2012),
# ...

# %%
sal.index
# Out:
# RangeIndex(start=0, stop=148654, step=1)

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
### Create own 5 questions of yours and solutions

# %%
sal['Agency'].value_counts()
# Out:
# San Francisco    148654
# Name: Agency, dtype: int64

# %% [markdown]
# #### How many jobs are getting highest overtime pay yearwise

# %%
sal.groupby(['Year'])[['OvertimePay','JobTitle']].max()
# Out:
#       OvertimePay            JobTitle
# Year
# 2011    245131.88         ZOO CURATOR
# 2012    220909.48  Youth Comm Advisor
# 2013    196689.18  Youth Comm Advisor
# 2014    173547.73  Youth Comm Advisor

# %%
sal[sal['OvertimePay'].isin(sal.groupby('Year')['OvertimePay'].aggregate(max))].count()
# Out:
# Id                  4
# EmployeeName        4
# JobTitle            4
# BasePay             4
# OvertimePay         4
# OtherPay            4
# Benefits            3
# TotalPay            4
# TotalPayBenefits    4
# Year                4
# Notes               0
# Agency              4
# Status              0
# dtype: int64

# %%
name=sal[sal['OvertimePay'].isin(sal.groupby('Year')['OvertimePay'].aggregate(max))]
name[['JobTitle','OvertimePay','Year']]
# Out:
#                                JobTitle  OvertimePay  Year
# 1       CAPTAIN III (POLICE DEPARTMENT)    245131.88  2011
# 36159      Lieutenant, Fire Suppression    220909.48  2012
# 72964                    Deputy Sheriff    196689.18  2013
# 110574                   Deputy Sheriff    173547.73  2014

# %% [markdown]
#     2011          4
#     2012          5
#     2013          5
#     2014          6

# %%
val=sal[sal['OvertimePay'].isin(sal.groupby('Year')['OvertimePay'].nlargest(10))]

# %%
val
# Out:
#             Id         EmployeeName  \
# 1            2         GARY JIMENEZ
# 17          18       SEBASTIAN WONG
# 35          36           KHOA TRINH
# 72          73       LAWRENCE FREED
# 88          89  EVETTE GEER-STEVENS
# 103        104        EDWARD DENNIS
# 114        115        CHARLES SCOTT
# 124        125       TYRONNE JULIAN
# 174        175         LAWRENCE LEE
# 180        181        DONALD BRYANT
# 36159    36160       Gary Altenberg
# 36161    36162           Khoa Trinh
# 36163    36164    Frederick Binkley
# 36199    36200       Scott Scholzen
# 36206    36207    Gregory Stangland
# 36221    36222            Alvin Lau
# 36238    36239       Martin Beltran
# 36312    36313       Ernest Johnson
# 36347    36348  Evette Geer-Stevens
# 36365    36366          Harold Byrd
# 72927    72928          Samson  Lai
# 72943    72944     Gary L Altenberg
# 72964    72965        Whitney P Yee
# 72973    72974   Frederick  Binkley
# 72988    72989       Oscar  Cabrera
# ...

# %%
a = sal.groupby(['Year'])[['OvertimePay']].max()
b= sal.groupby('Year')[['JobTitle']].count()

# %%
a
# Out:
#       OvertimePay
# Year
# 2011    245131.88
# 2012    220909.48
# 2013    196689.18
# 2014    173547.73

# %%
b
# Out:
#       JobTitle
# Year
# 2011     36159
# 2012     36766
# 2013     37606
# 2014     38123

# %%
temp = sal[sal['OvertimePay'].isin(sal.groupby("Year")['OvertimePay'].max())]

# %%
temp.groupby("Year")['JobTitle'].count()
# Out:
# Year
# 2011    1
# 2012    1
# 2013    1
# 2014    1
# Name: JobTitle, dtype: int64

# %%
a = sal.groupby("Year")['OvertimePay'].max()

# %%
a.index
# Out:
# Int64Index([2011, 2012, 2013, 2014], dtype='int64', name='Year')

# %%
a.values
# Out:
# array([245131.88, 220909.48, 196689.18, 173547.73])

# %%
((sal['Year'] == 2011) & (sal['OvertimePay'] == 245131.88)).sum()
# Out:
# 1

# %%
for i, v in zip(a.index, a.values):
    s = ((sal['Year'] == i) & (sal['OvertimePay'] == v)).sum()
    print(i, "\t", s)
# Out:
# 2011 	 1
# 2012 	 1
# 2013 	 1
# 2014 	 1
