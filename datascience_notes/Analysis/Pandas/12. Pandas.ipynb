# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tip = sns.load_dataset("tips")

# %% [markdown]
#      1. Find maximum tip and total bill paid per person

# %%
max(tip['tip']/tip['size'])
# Out:
# 3.3333333333333335

# %%
max(tip['total_bill']/tip['size'])
# Out:
# 20.275

# %% [markdown]
#     2. Range of tip and total bill paid by most of the customers.

# %%
tip['total_bill'].value_counts(bins=5)
# Out:
# (12.618, 22.166]    119
# (22.166, 31.714]     50
# (3.021, 12.618]      49
# (31.714, 41.262]     19
# (41.262, 50.81]       7
# Name: total_bill, dtype: int64

# %%
tip['total_bill'].value_counts(bins=7)
# Out:
# (9.89, 16.71]     93
# (16.71, 23.53]    69
# (23.53, 30.35]    36
# (3.021, 9.89]     16
# (30.35, 37.17]    16
# (37.17, 43.99]     8
# (43.99, 50.81]     6
# Name: total_bill, dtype: int64

# %%
val = tip['total_bill'].value_counts()

# %%
val[val == 3]
# Out:
# 13.42    3
# Name: total_bill, dtype: int64

# %%
val[val == 2]
# Out:
# 21.01    2
# 18.29    2
# 10.07    2
# 20.69    2
# 15.69    2
# 13.00    2
# 17.92    2
# 10.34    2
# 15.98    2
# 20.29    2
# 10.33    2
# 7.25     2
# 13.81    2
# Name: total_bill, dtype: int64

# %% [markdown]
#     Range is 7 to 21

# %% [markdown]
#     Does smoking effect the bill ?

# %%
tip.groupby("smoker")['total_bill'].sum()
# Out:
# smoker
# Yes    1930.34
# No     2897.43
# Name: total_bill, dtype: float64

# %%
tip.groupby("smoker")['total_bill'].mean()
# Out:
# smoker
# Yes    20.756344
# No     19.188278
# Name: total_bill, dtype: float64

# %%
tip.groupby("smoker")['total_bill'].count()
# Out:
# smoker
# Yes     93
# No     151
# Name: total_bill, dtype: int64

# %%
tip.groupby("smoker")['total_bill'].median()
# Out:
# smoker
# Yes    17.92
# No     17.59
# Name: total_bill, dtype: float64

# %% [markdown]
#     Any relation between the total bill and tip ? Explain

# %%
tip[['total_bill']].corrwith(tip['tip'])
# Out:
# total_bill    0.675734
# dtype: float64

# %%
plt.plot(tip['total_bill'], tip['tip'], 'o')

# %% [markdown]
#     What maximum percentage of total bill and tip paid per person?

# %%
tip['total_bill'].sum()/len(tip['total_bill'])
# Out:
# 19.78594262295082

# %%
(((tip['total_bill']/tip['size'])/tip['total_bill'].sum())*100)
# Out:
# 0      0.175961
# 1      0.071393
# 2      0.145064
# 3      0.245248
# 4      0.127336
#          ...
# 239    0.200438
# 240    0.281496
# 241    0.234787
# 242    0.184557
# 243    0.194500
# Length: 244, dtype: float64

# %%
max(((tip['total_bill']/tip['size'])/tip['total_bill'].sum())*100)
# Out:
# 0.4199661541457028

# %%
max(((tip['tip']/tip['size'])/tip['tip'].sum())*100)
# Out:
# 0.4556348360170226

# %% [markdown]
#     Does gender effects the choice of time?

# %%
tip.groupby("sex")['time'].value_counts()
# Out:
# sex     time
# Male    Dinner    124
#         Lunch      33
# Female  Dinner     52
#         Lunch      35
# Name: time, dtype: int64

# %%
### gender does not effect the time

# %% [markdown]
#     At what time I should increase my staff?

# %%
tip['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
df = pd.DataFrame(np.random.randn(10, 5), columns=list("ABCDE"))

# %%
df
# Out:
#           A         B         C         D         E
# 0  1.519630  1.164338  0.053445 -0.468651 -0.001316
# 1  1.418909 -1.490651  0.121168  0.370460 -1.587512
# 2 -0.804471 -0.210534 -0.869693  0.325624 -0.768585
# 3 -0.802052  0.370422  0.151396 -0.694881  1.008121
# 4  2.005001  0.401700 -0.499526 -0.543121 -1.615464
# 5  1.226134  0.220048  0.901415  0.181542  0.725900
# 6 -0.532857 -0.170163  0.034638  0.042758 -0.867440
# 7  0.365924  0.990637  0.825780  0.884428  0.278516
# 8  1.678557  1.582922  0.924012 -0.423414 -0.143577
# 9  0.890166  0.499851  0.595590  0.285543 -1.762673

# %%
df.drop("A")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-061541ad5de5> in <module>
# ----> 1 df.drop("A")
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df.drop(0)  # axis = 0, row(index) find
# Out:
#           A         B         C         D         E
# 1  1.418909 -1.490651  0.121168  0.370460 -1.587512
# 2 -0.804471 -0.210534 -0.869693  0.325624 -0.768585
# 3 -0.802052  0.370422  0.151396 -0.694881  1.008121
# 4  2.005001  0.401700 -0.499526 -0.543121 -1.615464
# 5  1.226134  0.220048  0.901415  0.181542  0.725900
# 6 -0.532857 -0.170163  0.034638  0.042758 -0.867440
# 7  0.365924  0.990637  0.825780  0.884428  0.278516
# 8  1.678557  1.582922  0.924012 -0.423414 -0.143577
# 9  0.890166  0.499851  0.595590  0.285543 -1.762673

# %%
df.drop("A", axis=1)
# axis = 1 for columns
# Out:
#           B         C         D         E
# 0  1.164338  0.053445 -0.468651 -0.001316
# 1 -1.490651  0.121168  0.370460 -1.587512
# 2 -0.210534 -0.869693  0.325624 -0.768585
# 3  0.370422  0.151396 -0.694881  1.008121
# 4  0.401700 -0.499526 -0.543121 -1.615464
# 5  0.220048  0.901415  0.181542  0.725900
# 6 -0.170163  0.034638  0.042758 -0.867440
# 7  0.990637  0.825780  0.884428  0.278516
# 8  1.582922  0.924012 -0.423414 -0.143577
# 9  0.499851  0.595590  0.285543 -1.762673

# %%
df['F'] = "Faltu"

# %%
df
# Out:
#           A         B         C         D         E      F
# 0  1.519630  1.164338  0.053445 -0.468651 -0.001316  Faltu
# 1  1.418909 -1.490651  0.121168  0.370460 -1.587512  Faltu
# 2 -0.804471 -0.210534 -0.869693  0.325624 -0.768585  Faltu
# 3 -0.802052  0.370422  0.151396 -0.694881  1.008121  Faltu
# 4  2.005001  0.401700 -0.499526 -0.543121 -1.615464  Faltu
# 5  1.226134  0.220048  0.901415  0.181542  0.725900  Faltu
# 6 -0.532857 -0.170163  0.034638  0.042758 -0.867440  Faltu
# 7  0.365924  0.990637  0.825780  0.884428  0.278516  Faltu
# 8  1.678557  1.582922  0.924012 -0.423414 -0.143577  Faltu
# 9  0.890166  0.499851  0.595590  0.285543 -1.762673  Faltu

# %%
df.drop("F", axis=1)
# Out:
#           A         B         C         D         E
# 0  1.519630  1.164338  0.053445 -0.468651 -0.001316
# 1  1.418909 -1.490651  0.121168  0.370460 -1.587512
# 2 -0.804471 -0.210534 -0.869693  0.325624 -0.768585
# 3 -0.802052  0.370422  0.151396 -0.694881  1.008121
# 4  2.005001  0.401700 -0.499526 -0.543121 -1.615464
# 5  1.226134  0.220048  0.901415  0.181542  0.725900
# 6 -0.532857 -0.170163  0.034638  0.042758 -0.867440
# 7  0.365924  0.990637  0.825780  0.884428  0.278516
# 8  1.678557  1.582922  0.924012 -0.423414 -0.143577
# 9  0.890166  0.499851  0.595590  0.285543 -1.762673

# %%
df.drop("F", axis=1, inplace=True)
# will change the actual df. It will not return

# %%
df
# Out:
#           A         B         C         D         E
# 0  1.519630  1.164338  0.053445 -0.468651 -0.001316
# 1  1.418909 -1.490651  0.121168  0.370460 -1.587512
# 2 -0.804471 -0.210534 -0.869693  0.325624 -0.768585
# 3 -0.802052  0.370422  0.151396 -0.694881  1.008121
# 4  2.005001  0.401700 -0.499526 -0.543121 -1.615464
# 5  1.226134  0.220048  0.901415  0.181542  0.725900
# 6 -0.532857 -0.170163  0.034638  0.042758 -0.867440
# 7  0.365924  0.990637  0.825780  0.884428  0.278516
# 8  1.678557  1.582922  0.924012 -0.423414 -0.143577
# 9  0.890166  0.499851  0.595590  0.285543 -1.762673

# %%
df.drop(['A', 'E'], axis=1)
# Out:
#           B         C         D
# 0  1.164338  0.053445 -0.468651
# 1 -1.490651  0.121168  0.370460
# 2 -0.210534 -0.869693  0.325624
# 3  0.370422  0.151396 -0.694881
# 4  0.401700 -0.499526 -0.543121
# 5  0.220048  0.901415  0.181542
# 6 -0.170163  0.034638  0.042758
# 7  0.990637  0.825780  0.884428
# 8  1.582922  0.924012 -0.423414
# 9  0.499851  0.595590  0.285543

# %%
df.drop([0, 3, 4, 9])
# Out:
#           A         B         C         D         E
# 1  1.418909 -1.490651  0.121168  0.370460 -1.587512
# 2 -0.804471 -0.210534 -0.869693  0.325624 -0.768585
# 5  1.226134  0.220048  0.901415  0.181542  0.725900
# 6 -0.532857 -0.170163  0.034638  0.042758 -0.867440
# 7  0.365924  0.990637  0.825780  0.884428  0.278516
# 8  1.678557  1.582922  0.924012 -0.423414 -0.143577

# %%
help(df.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise') method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by specifying directly index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Whether to drop labels from the index (0 or 'index') or
#         columns (1 or 'columns').
#     index : single label or list-like
#         Alternative to specifying axis (``labels, axis=0``
#         is equivalent to ``index=labels``).
#     columns : single label or list-like
# ...

# %%
df.drop(columns=['A'])
# Out:
#           B         C         D         E
# 0  1.164338  0.053445 -0.468651 -0.001316
# 1 -1.490651  0.121168  0.370460 -1.587512
# 2 -0.210534 -0.869693  0.325624 -0.768585
# 3  0.370422  0.151396 -0.694881  1.008121
# 4  0.401700 -0.499526 -0.543121 -1.615464
# 5  0.220048  0.901415  0.181542  0.725900
# 6 -0.170163  0.034638  0.042758 -0.867440
# 7  0.990637  0.825780  0.884428  0.278516
# 8  1.582922  0.924012 -0.423414 -0.143577
# 9  0.499851  0.595590  0.285543 -1.762673

# %%
df.drop(index=[0, 8])
# Out:
#           A         B         C         D         E
# 1  1.418909 -1.490651  0.121168  0.370460 -1.587512
# 2 -0.804471 -0.210534 -0.869693  0.325624 -0.768585
# 3 -0.802052  0.370422  0.151396 -0.694881  1.008121
# 4  2.005001  0.401700 -0.499526 -0.543121 -1.615464
# 5  1.226134  0.220048  0.901415  0.181542  0.725900
# 6 -0.532857 -0.170163  0.034638  0.042758 -0.867440
# 7  0.365924  0.990637  0.825780  0.884428  0.278516
# 9  0.890166  0.499851  0.595590  0.285543 -1.762673

# %%
df.drop(index=1, axis=1)
# Out:
#           A         B         C         D         E
# 0  1.519630  1.164338  0.053445 -0.468651 -0.001316
# 2 -0.804471 -0.210534 -0.869693  0.325624 -0.768585
# 3 -0.802052  0.370422  0.151396 -0.694881  1.008121
# 4  2.005001  0.401700 -0.499526 -0.543121 -1.615464
# 5  1.226134  0.220048  0.901415  0.181542  0.725900
# 6 -0.532857 -0.170163  0.034638  0.042758 -0.867440
# 7  0.365924  0.990637  0.825780  0.884428  0.278516
# 8  1.678557  1.582922  0.924012 -0.423414 -0.143577
# 9  0.890166  0.499851  0.595590  0.285543 -1.762673

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
ord('a')
# Out:
# 97

# %%
df.index = [chr(i) for i in range(75, 85)]

# %%
df
# Out:
#           A         B         C         D         E
# K  1.519630  1.164338  0.053445 -0.468651 -0.001316
# L  1.418909 -1.490651  0.121168  0.370460 -1.587512
# M -0.804471 -0.210534 -0.869693  0.325624 -0.768585
# N -0.802052  0.370422  0.151396 -0.694881  1.008121
# O  2.005001  0.401700 -0.499526 -0.543121 -1.615464
# P  1.226134  0.220048  0.901415  0.181542  0.725900
# Q -0.532857 -0.170163  0.034638  0.042758 -0.867440
# R  0.365924  0.990637  0.825780  0.884428  0.278516
# S  1.678557  1.582922  0.924012 -0.423414 -0.143577
# T  0.890166  0.499851  0.595590  0.285543 -1.762673

# %%
df.drop('K')
# Out:
#           A         B         C         D         E
# L  1.418909 -1.490651  0.121168  0.370460 -1.587512
# M -0.804471 -0.210534 -0.869693  0.325624 -0.768585
# N -0.802052  0.370422  0.151396 -0.694881  1.008121
# O  2.005001  0.401700 -0.499526 -0.543121 -1.615464
# P  1.226134  0.220048  0.901415  0.181542  0.725900
# Q -0.532857 -0.170163  0.034638  0.042758 -0.867440
# R  0.365924  0.990637  0.825780  0.884428  0.278516
# S  1.678557  1.582922  0.924012 -0.423414 -0.143577
# T  0.890166  0.499851  0.595590  0.285543 -1.762673

# %%
df.drop(index = "N")
# Out:
#           A         B         C         D         E
# K  1.519630  1.164338  0.053445 -0.468651 -0.001316
# L  1.418909 -1.490651  0.121168  0.370460 -1.587512
# M -0.804471 -0.210534 -0.869693  0.325624 -0.768585
# O  2.005001  0.401700 -0.499526 -0.543121 -1.615464
# P  1.226134  0.220048  0.901415  0.181542  0.725900
# Q -0.532857 -0.170163  0.034638  0.042758 -0.867440
# R  0.365924  0.990637  0.825780  0.884428  0.278516
# S  1.678557  1.582922  0.924012 -0.423414 -0.143577
# T  0.890166  0.499851  0.595590  0.285543 -1.762673

# %% [markdown]
#     row --> axis = 0, index
#     column --> axis = 1, columns

# %%
tit = sns.load_dataset("titanic")

# %%
tit.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tit.drop(['sex', 'survived', 'embarked', 'pclass'], axis=1, inplace=True)

# %%
tit.head()
# Out:
#     age  sibsp  parch     fare  class    who  adult_male deck  embark_town  \
# 0  22.0      1      0   7.2500  Third    man        True  NaN  Southampton
# 1  38.0      1      0  71.2833  First  woman       False    C    Cherbourg
# 2  26.0      0      0   7.9250  Third  woman       False  NaN  Southampton
# 3  35.0      1      0  53.1000  First  woman       False    C  Southampton
# 4  35.0      0      0   8.0500  Third    man        True  NaN  Southampton
#
#   alive  alone
# 0    no  False
# 1   yes  False
# 2   yes   True
# 3   yes  False
# 4    no   True

# %% [markdown]
# ### Outliers Detect
#         1. Visualization
#         2. z-index
#         3. IQR
