# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
apple = pd.read_csv("D:/G_Drive/internship/datascience/DS_Assignments/Apple_Stock/appl_1980_2014.csv")

# %%
apple.head()
# Out:
#          Date   Open   High    Low  Close    Volume  Adj Close
# 0  2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1  2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2  2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 3  2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 4  2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %%
apple.set_index("Date", inplace=True)  # changing in main data inspite of returning it

# %%
apple.index = pd.to_datetime(apple.index)

# %%
apple.head()
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %%
apple.reset_index(level=0)
# Out:
#            Date   Open   High    Low  Close     Volume  Adj Close
# 0    2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1    2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2    2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3    2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4    2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...         ...    ...    ...    ...    ...        ...        ...
# 8460 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %% [markdown]
#     How many months in the data we have?

# %%
apple.index.strftime("%m").__len__()
# Out:
# 8465

# %% [markdown]
#     Step 9. Get the last business day of each month

# %%
apple.sort_index(inplace=True)

# %%
apple.head()
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41

# %%
apple.last("M")
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52
# 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35

# %%
apple.last("D")
# Out:
#              Open  High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08  96.27  96.8  93.92  95.35  65130000      95.35

# %%
apple.last("5M")
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 2014-03-03  523.42  530.65  522.81  527.76  59695300      74.98
# 2014-03-04  531.00  532.64  527.77  531.24  64785000      75.47
# 2014-03-05  530.92  534.75  529.13  532.36  50015700      75.63
# 2014-03-06  532.79  534.44  528.10  530.75  46372200      75.40
# 2014-03-07  531.09  531.98  526.05  530.44  55182400      75.36
# ...            ...     ...     ...     ...       ...        ...
# 2014-07-01   93.52   94.07   93.13   93.52  38170200      93.52
# 2014-07-02   93.87   94.06   93.09   93.48  28420900      93.48
# 2014-07-03   93.67   94.10   93.20   94.03  22891800      94.03
# 2014-07-07   94.14   95.99   94.10   95.97  56305400      95.97
# 2014-07-08   96.27   96.80   93.92   95.35  65130000      95.35
#
# [89 rows x 6 columns]

# %%
apple.last("10D")
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-06-30  92.10  93.73  92.09  92.93  49482300      92.93
# 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52
# 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35

# %%
apple.last("Y")
# Out:
#               Open    High     Low   Close     Volume  Adj Close
# Date
# 2014-01-02  555.68  557.03  552.02  553.13   58671200      78.11
# 2014-01-03  552.86  553.70  540.43  540.98   98116900      76.40
# 2014-01-06  537.45  546.80  533.60  543.93  103152700      76.81
# 2014-01-07  544.32  545.96  537.92  540.04   79302300      76.26
# 2014-01-08  538.81  545.56  538.69  543.46   64632400      76.75
# ...            ...     ...     ...     ...        ...        ...
# 2014-07-01   93.52   94.07   93.13   93.52   38170200      93.52
# 2014-07-02   93.87   94.06   93.09   93.48   28420900      93.48
# 2014-07-03   93.67   94.10   93.20   94.03   22891800      94.03
# 2014-07-07   94.14   95.99   94.10   95.97   56305400      95.97
# 2014-07-08   96.27   96.80   93.92   95.35   65130000      95.35
#
# [129 rows x 6 columns]

# %%
apple.last("2Y")
# Out:
#               Open    High     Low   Close     Volume  Adj Close
# Date
# 2013-01-02  553.82  555.00  541.63  549.03  140129500      75.63
# 2013-01-03  547.88  549.67  541.00  542.10   88241300      74.68
# 2013-01-04  536.97  538.63  525.83  527.00  148583400      72.60
# 2013-01-07  522.00  529.30  515.20  523.90  121039100      72.17
# 2013-01-08  529.21  531.89  521.25  525.31  114676800      72.37
# ...            ...     ...     ...     ...        ...        ...
# 2014-07-01   93.52   94.07   93.13   93.52   38170200      93.52
# 2014-07-02   93.87   94.06   93.09   93.48   28420900      93.48
# 2014-07-03   93.67   94.10   93.20   94.03   22891800      94.03
# 2014-07-07   94.14   95.99   94.10   95.97   56305400      95.97
# 2014-07-08   96.27   96.80   93.92   95.35   65130000      95.35
#
# [381 rows x 6 columns]

# %%
apple.last("5Y")
# Out:
#               Open    High     Low   Close     Volume  Adj Close
# Date
# 2010-01-04  213.43  214.50  212.38  214.01  123432400      29.22
# 2010-01-05  214.60  215.59  213.25  214.38  150476200      29.27
# 2010-01-06  214.38  215.23  210.75  210.97  138040000      28.81
# 2010-01-07  211.75  212.00  209.05  210.58  119282800      28.75
# 2010-01-08  210.30  212.00  209.06  211.98  111902700      28.94
# ...            ...     ...     ...     ...        ...        ...
# 2014-07-01   93.52   94.07   93.13   93.52   38170200      93.52
# 2014-07-02   93.87   94.06   93.09   93.48   28420900      93.48
# 2014-07-03   93.67   94.10   93.20   94.03   22891800      94.03
# 2014-07-07   94.14   95.99   94.10   95.97   56305400      95.97
# 2014-07-08   96.27   96.80   93.92   95.35   65130000      95.35
#
# [1135 rows x 6 columns]

# %%
apple.last("48H")
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35

# %%
apple.head()
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41

# %%
apple.resample("D").count()
# Out:
#             Open  High  Low  Close  Volume  Adj Close
# Date
# 1980-12-12     1     1    1      1       1          1
# 1980-12-13     0     0    0      0       0          0
# 1980-12-14     0     0    0      0       0          0
# 1980-12-15     1     1    1      1       1          1
# 1980-12-16     1     1    1      1       1          1
# ...          ...   ...  ...    ...     ...        ...
# 2014-07-04     0     0    0      0       0          0
# 2014-07-05     0     0    0      0       0          0
# 2014-07-06     0     0    0      0       0          0
# 2014-07-07     1     1    1      1       1          1
# 2014-07-08     1     1    1      1       1          1
#
# [12262 rows x 6 columns]

# %%
apple.resample("M").count()
# Out:
#             Open  High  Low  Close  Volume  Adj Close
# Date
# 1980-12-31    13    13   13     13      13         13
# 1981-01-31    21    21   21     21      21         21
# 1981-02-28    19    19   19     19      19         19
# 1981-03-31    22    22   22     22      22         22
# 1981-04-30    21    21   21     21      21         21
# ...          ...   ...  ...    ...     ...        ...
# 2014-03-31    21    21   21     21      21         21
# 2014-04-30    21    21   21     21      21         21
# 2014-05-31    21    21   21     21      21         21
# 2014-06-30    21    21   21     21      21         21
# 2014-07-31     5     5    5      5       5          5
#
# [404 rows x 6 columns]

# %%
apple.resample("M").sum()
# Out:
#                 Open      High       Low     Close      Volume  Adj Close
# Date
# 1980-12-31    396.26    397.38    395.76    395.76   336212800       6.15
# 1981-01-31    666.85    668.36    664.75    664.75   152247200      10.37
# 1981-02-28    503.12    504.87    501.75    501.75    80404800       7.81
# 1981-03-31    548.63    550.37    546.40    546.40   175179200       8.53
# 1981-04-30    573.02    574.73    571.77    571.77   134232000       8.89
# ...              ...       ...       ...       ...         ...        ...
# 2014-03-31  11205.46  11265.53  11131.49  11197.50  1250424700    1590.75
# 2014-04-30  11341.72  11431.33  11261.51  11362.56  1608765200    1614.21
# 2014-05-31  12627.34  12733.83  12564.99  12667.11  1433917100    1807.23
# 2014-06-30   4669.56   4705.77   4635.45   4675.82  1206556300    1929.60
# 2014-07-31    471.47    475.02    467.44    472.35   210918300     472.35
#
# [404 rows x 6 columns]

# %%
apple.resample("M").max()
# Out:
#               Open    High     Low   Close     Volume  Adj Close
# Date
# 1980-12-31   36.00   36.13   36.00   36.00  117258400       0.56
# 1981-01-31   34.50   34.75   34.50   34.50   13921600       0.54
# 1981-02-28   28.75   28.87   28.75   28.75    6966400       0.45
# 1981-03-31   26.75   27.00   26.75   26.75   57825600       0.42
# 1981-04-30   29.25   29.37   29.25   29.25   14504000       0.46
# ...            ...     ...     ...     ...        ...        ...
# 2014-03-31  546.52  549.00  539.59  544.99   93511600      77.42
# 2014-04-30  593.74  599.43  589.80  594.09  189977900      84.40
# 2014-05-31  637.98  644.17  628.90  635.38  141005200      90.77
# 2014-06-30  649.90  651.26  644.47  647.35  100813200      94.25
# 2014-07-31   96.27   96.80   94.10   95.97   65130000      95.97
#
# [404 rows x 6 columns]

# %%
apple.resample("Y").count()
# Out:
#             Open  High  Low  Close  Volume  Adj Close
# Date
# 1980-12-31    13    13   13     13      13         13
# 1981-12-31   252   252  252    252     252        252
# 1982-12-31   253   253  253    253     253        253
# 1983-12-31   252   252  252    252     252        252
# 1984-12-31   253   253  253    253     253        253
# 1985-12-31   253   253  253    253     253        253
# 1986-12-31   253   253  253    253     253        253
# 1987-12-31   253   253  253    253     253        253
# 1988-12-31   253   253  253    253     253        253
# 1989-12-31   252   252  252    252     252        252
# 1990-12-31   253   253  253    253     253        253
# 1991-12-31   253   253  253    253     253        253
# 1992-12-31   254   254  254    254     254        254
# 1993-12-31   253   253  253    253     253        253
# 1994-12-31   252   252  252    252     252        252
# 1995-12-31   252   252  252    252     252        252
# ...

# %%
apple.resample("2Y").max()
# Out:
#               Open    High     Low   Close      Volume  Adj Close
# Date
# 1980-12-31   36.00   36.13   36.00   36.00   117258400       0.56
# 1982-12-31   34.50   34.88   34.50   34.50    89269600       0.54
# 1984-12-31   62.75   63.25   61.37   62.75   305379200       0.98
# 1986-12-31   43.63   43.87   42.62   43.75   226032800       0.68
# 1988-12-31   80.50   82.25   79.75   80.25   194320000       1.85
# 1990-12-31   49.75   50.38   48.50   49.62   531792800       1.57
# 1992-12-31   72.50   73.25   70.00   72.75   467093200       2.35
# 1994-12-31   64.00   65.25   63.75   65.00   530149200       2.14
# 1996-12-31   49.00   50.13   48.63   49.37   302990800       1.68
# 1998-12-31   43.50   43.75   42.25   43.00  1047620000       1.47
# 2000-12-31  142.44  150.38  140.00  144.19  1855410200       4.92
# 2002-12-31   26.70   27.12   25.76   26.59   468417600       1.82
# 2004-12-31   68.95   69.57   67.41   68.44   692106800       4.67
# ...

# %%
apple.resample("2M").max()
# Out:
#               Open    High     Low   Close     Volume  Adj Close
# Date
# 1980-12-31   36.00   36.13   36.00   36.00  117258400       0.56
# 1981-02-28   34.50   34.75   34.50   34.50   13921600       0.54
# 1981-04-30   29.25   29.37   29.25   29.25   57825600       0.46
# 1981-06-30   33.13   33.25   33.13   33.13   37374400       0.52
# 1981-08-31   26.13   26.25   26.13   26.13   42616000       0.41
# ...            ...     ...     ...     ...        ...        ...
# 2013-12-31  572.65  575.14  566.41  570.09  141465800      80.51
# 2014-02-28  555.68  560.20  552.02  557.36  266380800      78.71
# 2014-04-30  593.74  599.43  589.80  594.09  189977900      84.40
# 2014-06-30  649.90  651.26  644.47  647.35  141005200      94.25
# 2014-08-31   96.27   96.80   94.10   95.97   65130000      95.97
#
# [203 rows x 6 columns]

# %%
apple.resample("M").count().head()
# Out:
#             Open  High  Low  Close  Volume  Adj Close
# Date
# 1980-12-31    13    13   13     13      13         13
# 1981-01-31    21    21   21     21      21         21
# 1981-02-28    19    19   19     19      19         19
# 1981-03-31    22    22   22     22      22         22
# 1981-04-30    21    21   21     21      21         21

# %%
apple.resample("BM").count().head() # BM --> Last Business day Month
# Out:
#             Open  High  Low  Close  Volume  Adj Close
# Date
# 1980-12-31    13    13   13     13      13         13
# 1981-01-30    21    21   21     21      21         21
# 1981-02-27    19    19   19     19      19         19
# 1981-03-31    22    22   22     22      22         22
# 1981-04-30    21    21   21     21      21         21

# %%
# resample

# %%
help(apple.resample)
# Out:
# Help on method resample in module pandas.core.generic:
#
# resample(rule, axis=0, closed: 'Optional[str]' = None, label: 'Optional[str]' = None, convention: 'str' = 'start', kind: 'Optional[str]' = None, loffset=None, base: 'Optional[int]' = None, on=None, level=None, origin: 'Union[str, TimestampConvertibleTypes]' = 'start_day', offset: 'Optional[TimedeltaConvertibleTypes]' = None) -> 'Resampler' method of pandas.core.frame.DataFrame instance
#     Resample time-series data.
#
#     Convenience method for frequency conversion and resampling of time
#     series. Object must have a datetime-like index (`DatetimeIndex`,
#     `PeriodIndex`, or `TimedeltaIndex`), or pass datetime-like values
#     to the `on` or `level` keyword.
#
#     Parameters
#     ----------
#     rule : DateOffset, Timedelta or str
#         The offset string or object representing target conversion.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %% [markdown]
#     2-3 questions/solutions on apple
#     2-3 questions/solutions on salary
