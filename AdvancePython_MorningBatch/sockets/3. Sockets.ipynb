# %%
# !ipconfig
# Out:
# Windows IP Configuration
#
#
# Ethernet adapter Ethernet:
#
#    Media State . . . . . . . . . . . : Media disconnected
#    Connection-specific DNS Suffix  . :
#
# Wireless LAN adapter Local Area Connection* 1:
#
#    Media State . . . . . . . . . . . : Media disconnected
#    Connection-specific DNS Suffix  . :
#
# Wireless LAN adapter Local Area Connection* 10:
#
#    Media State . . . . . . . . . . . : Media disconnected
#    Connection-specific DNS Suffix  . :
#
# Wireless LAN adapter Wi-Fi:
#
#    Connection-specific DNS Suffix  . :
#    IPv6 Address. . . . . . . . . . . : 2402:e280:2307:37e:9b4:2aa4:2b0d:2365
#    Temporary IPv6 Address. . . . . . : 2402:e280:2307:37e:9073:dbcd:4ef9:13eb
#    Link-local IPv6 Address . . . . . : fe80::9b4:2aa4:2b0d:2365%9
#    IPv4 Address. . . . . . . . . . . : 192.168.1.7
#    Subnet Mask . . . . . . . . . . . : 255.255.255.0
#    Default Gateway . . . . . . . . . : fe80::1%9
#                                        192.168.1.254
#
# ...

# %% [markdown]
# ### Sockets
#
#     It works at the transport layer.
#
#         Medium between systems or hosts or application
#
#             Here we will create local socket(same network)
#
#     Socket
#         It will work at an IP and PORT
#
#             Port --> A unique number given to application to identify them
#
#
#      2 Systems --> Socket
#
#          Server             Client

# %%
### range of port number

# %%
from IPython.display import Image

# %%
import requests

# %%
resp = requests.get("https://files.realpython.com/media/sockets-tcp-flow.1da426797e37.jpg")
with open("sockets_process.jpg", 'wb') as fp:
    fp.write(resp.content)

# %%
Image("sockets_process.jpg")

# %%
import socket

# %% [markdown]
#     Whenever you create socket you need to define the type of IP(IPv4, IPv6) you are using
#     and protocol you are using (TCP or UDP)

# %% [markdown]
# ### TCP
#         Transfer Control Protocol
#             Connection Oriented
#
# ### UDP
#         User Datagram Protocol
#             Connection Less

# %%
server = socket.socket(socket.AF_INET, socket.SOCK_STREAM)  # AF_INET --> Ipv4, Sock_stream --> TCP

# %%
server
# Out:
# <socket.socket fd=1448, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0>

# %%
# !ipconfig
# Out:
# Windows IP Configuration
#
#
# Ethernet adapter Ethernet:
#
#    Media State . . . . . . . . . . . : Media disconnected
#    Connection-specific DNS Suffix  . :
#
# Wireless LAN adapter Local Area Connection* 1:
#
#    Media State . . . . . . . . . . . : Media disconnected
#    Connection-specific DNS Suffix  . :
#
# Wireless LAN adapter Local Area Connection* 10:
#
#    Media State . . . . . . . . . . . : Media disconnected
#    Connection-specific DNS Suffix  . :
#
# Wireless LAN adapter Wi-Fi:
#
#    Connection-specific DNS Suffix  . :
#    IPv6 Address. . . . . . . . . . . : 2402:e280:2307:37e:9b4:2aa4:2b0d:2365
#    Temporary IPv6 Address. . . . . . : 2402:e280:2307:37e:9073:dbcd:4ef9:13eb
#    Link-local IPv6 Address . . . . . : fe80::9b4:2aa4:2b0d:2365%9
#    IPv4 Address. . . . . . . . . . . : 192.168.1.7
#    Subnet Mask . . . . . . . . . . . : 255.255.255.0
#    Default Gateway . . . . . . . . . : fe80::1%9
#                                        192.168.1.254
#
# ...

# %%
ip = "192.168.1.7"
port = 1234

server.bind((ip, port))

# %%
# %%writefile server.py
import socket

server = socket.socket(socket.AF_INET, socket.SOCK_STREAM)  # AF_INET --> Ipv4, Sock_stream --> TCP
ip = "192.168.1.7"
port = 1234

server.bind((ip, port))
server.listen()
print(f"\n Server is listening at IP : {ip} and PORT : {port}")
client = server.accept()
print(client)
# Out:
# Overwriting server.py

# %%
server.close()

# %%
# %%writefile client.py
import socket

sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

ip = "192.168.1.7"
port = 1234
sock.connect((ip, port)) # get connected with server

print("\n Connected with server")
# Out:
# Overwriting client.py
